# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report, accuracy_score
from sklearn import linear_model
import scipy.stats as stat
import pickle
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
loan_data_inputs_train = pd.read_csv('loan_data_inputs_train.csv', index_col = 0)
loan_data_targets_train = pd.read_csv('loan_data_targets_train.csv', index_col = 0, header = None)
loan_data_inputs_test = pd.read_csv('loan_data_inputs_test.csv', index_col = 0)
loan_data_targets_test = pd.read_csv('loan_data_targets_test.csv', index_col = 0, header = None)

# %%
loan_data_inputs_train.head()
# Out:
#               id  member_id  loan_amnt  funded_amnt  funded_amnt_inv  \
# 427211  12796369   14818505      24000        24000          24000.0
# 206088   1439740    1691948      10000        10000          10000.0
# 136020   5214749    6556909      20425        20425          20425.0
# 412305  13827698   15890016      17200        17200          17200.0
# 36159     422455     496525       8400         8400           7450.0
#
#               term  int_rate  installment grade sub_grade  ... dti:21.7-22.4  \
# 427211   36 months      8.90       762.08     A        A5  ...             1
# 206088   36 months     14.33       343.39     C        C1  ...             0
# 136020   36 months      8.90       648.56     A        A5  ...             0
# 412305   36 months     16.59       609.73     D        D1  ...             0
# 36159    36 months     12.84       282.40     C        C2  ...             0
#
#        dti:22.4-35 dti:>35  mths_since_last_record:Missing  \
# 427211           0       0                               1
# 206088           0       0                               1
# 136020           0       0                               1
# 412305           0       0                               1
# 36159            1       0                               1
#
#        mths_since_last_record:0-2 mths_since_last_record:3-20  \
# 427211                          0                           0
# 206088                          0                           0
# 136020                          0                           0
# 412305                          0                           0
# 36159                           0                           0
#
#        mths_since_last_record:21-31 mths_since_last_record:32-80  \
# 427211                            0                            0
# 206088                            0                            0
# 136020                            0                            0
# 412305                            0                            0
# 36159                             0                            0
#
#        mths_since_last_record:81-86 mths_since_last_record:>86
# 427211                            0                          0
# 206088                            0                          0
# 136020                            0                          0
# 412305                            0                          0
# 36159                             0                          0
#
# [5 rows x 313 columns]

# %%
loan_data_targets_train.head()
# Out:
#         1
# 0
# 427211  1
# 206088  1
# 136020  1
# 412305  0
# 36159   0

# %% [markdown]
# #### Creating dataset for inputdata

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'delinq_2yrs:0',
'delinq_2yrs:1-3',
'delinq_2yrs:>=4',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'open_acc:0',
'open_acc:1-3',
'open_acc:4-12',
'open_acc:13-17',
'open_acc:18-22',
'open_acc:23-25',
'open_acc:26-30',
'open_acc:>=31',
'pub_rec:0-2',
'pub_rec:3-4',
'pub_rec:>=5',
'total_acc:<=27',
'total_acc:28-51',
'total_acc:>=52',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'total_rev_hi_lim:<=5K',
'total_rev_hi_lim:5K-10K',
'total_rev_hi_lim:10K-20K',
'total_rev_hi_lim:20K-30K',
'total_rev_hi_lim:30K-40K',
'total_rev_hi_lim:40K-55K',
'total_rev_hi_lim:55K-95K',
'total_rev_hi_lim:>95K',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86',
]]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'delinq_2yrs:>=4',
'inq_last_6mths:>6',
'open_acc:0',
'pub_rec:0-2',
'total_acc:<=27',
'acc_now_delinq:0',
'total_rev_hi_lim:<=5K',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1) 
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>86
# 427211                           0
# 206088                           0
# 136020                           0
# 412305                           0
# 36159                            0
#
# [5 rows x 99 columns]

# %%
reg = LogisticRegression()
reg.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
reg.intercept_
# Out:
# array([-1.32764093])

# %%
reg.coef_
# Out:
# array([[ 1.14976578,  0.90212922,  0.7040257 ,  0.51386421,  0.33438729,
#          0.14345737,  0.09930948,  0.11206899,  0.03713551,  0.05810378,
#          0.05909245,  0.06138693,  0.07840143,  0.13695864,  0.09919838,
#          0.18495283,  0.24796064,  0.22457679,  0.26304965,  0.32286987,
#          0.51401558,  0.08372931, -0.01456657,  0.3064358 ,  0.20289546,
#          0.21609193,  0.26758834,  0.05436195,  0.07584308,  0.0913517 ,
#          0.11585946,  0.08168547,  0.05507298,  0.12801008,  1.0493267 ,
#          0.85052637,  0.75122097,  0.5510975 ,  0.38977879,  0.14664849,
#         -0.0807416 ,  0.8730417 ,  0.55098455,  0.29890218,  0.10762119,
#          0.07530965,  0.03684164,  0.66589478,  0.52160662,  0.31012452,
#          0.00580487, -0.09487892, -0.12306339, -0.14125924, -0.14765503,
#         -0.11193526, -0.20331242,  0.12191812,  0.17828254, -0.01175015,
#          0.04072882,  0.20881601,  0.04349592,  0.01422216,  0.01707683,
#          0.03715022,  0.06325753,  0.09624028,  0.24947935, -0.06460365,
#          0.00622445,  0.1055035 ,  0.17588889,  0.25301499,  0.3275976 ,
#          0.4042497 ,  0.42411676,  0.50360533,  0.59474706,  0.52363242,
#          0.20337446,  0.32893416,  0.36129139,  0.30310807,  0.22824463,
#          0.13111894,  0.12144415,  0.08688172,  0.04761707,  0.06475454,
#          0.14204451,  0.1549113 ,  0.10594559,  0.35788425,  0.46080352,
#          0.39240609,  0.55979183,  0.22204676,  0.28317551]])

# %%
class LogisticRegression_with_p_values:
    
    def __init__(self,*args,**kwargs):
        self.model = linear_model.LogisticRegression(*args,**kwargs)

    def fit(self,X,y):
        self.model.fit(X,y)
        denom = (2.0 * (1.0 + np.cosh(self.model.decision_function(X))))
        denom = np.tile(denom,(X.shape[1],1)).T
        F_ij = np.dot((X / denom).T,X)
        Cramer_Rao = np.linalg.inv(F_ij)
        sigma_estimates = np.sqrt(np.diagonal(Cramer_Rao))
        z_scores = self.model.coef_[0] / sigma_estimates
        p_values = [stat.norm.sf(abs(x)) * 2 for x in z_scores]
        self.coef_ = self.model.coef_
        self.intercept_ = self.model.intercept_
        self.p_values = p_values

# %%
loan_data_inputs_train.shape
# Out:
# (373028, 313)

# %%
loan_data_targets_train.shape
# Out:
# (373028, 1)

# %%
loan_data_inputs_test.shape
# Out:
# (93257, 313)

# %%
loan_data_targets_test.shape
# Out:
# (93257, 1)

# %%
reg1 = LogisticRegression_with_p_values()
reg1.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_name = inputs_train.columns.values

# %%
reg1.intercept_
# Out:
# array([-1.32764093])

# %%
reg1.coef_
# Out:
# array([[ 1.14976578,  0.90212922,  0.7040257 ,  0.51386421,  0.33438729,
#          0.14345737,  0.09930948,  0.11206899,  0.03713551,  0.05810378,
#          0.05909245,  0.06138693,  0.07840143,  0.13695864,  0.09919838,
#          0.18495283,  0.24796064,  0.22457679,  0.26304965,  0.32286987,
#          0.51401558,  0.08372931, -0.01456657,  0.3064358 ,  0.20289546,
#          0.21609193,  0.26758834,  0.05436195,  0.07584308,  0.0913517 ,
#          0.11585946,  0.08168547,  0.05507298,  0.12801008,  1.0493267 ,
#          0.85052637,  0.75122097,  0.5510975 ,  0.38977879,  0.14664849,
#         -0.0807416 ,  0.8730417 ,  0.55098455,  0.29890218,  0.10762119,
#          0.07530965,  0.03684164,  0.66589478,  0.52160662,  0.31012452,
#          0.00580487, -0.09487892, -0.12306339, -0.14125924, -0.14765503,
#         -0.11193526, -0.20331242,  0.12191812,  0.17828254, -0.01175015,
#          0.04072882,  0.20881601,  0.04349592,  0.01422216,  0.01707683,
#          0.03715022,  0.06325753,  0.09624028,  0.24947935, -0.06460365,
#          0.00622445,  0.1055035 ,  0.17588889,  0.25301499,  0.3275976 ,
#          0.4042497 ,  0.42411676,  0.50360533,  0.59474706,  0.52363242,
#          0.20337446,  0.32893416,  0.36129139,  0.30310807,  0.22824463,
#          0.13111894,  0.12144415,  0.08688172,  0.04761707,  0.06475454,
#          0.14204451,  0.1549113 ,  0.10594559,  0.35788425,  0.46080352,
#          0.39240609,  0.55979183,  0.22204676,  0.28317551]])

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg1.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg1.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                     Feature name  Coefficients
# 0                      Intercept     -1.327641
# 1                        grade:A      1.149766
# 2                        grade:B      0.902129
# 3                        grade:C      0.704026
# 4                        grade:D      0.513864
# ..                           ...           ...
# 95   mths_since_last_record:3-20      0.460804
# 96  mths_since_last_record:21-31      0.392406
# 97  mths_since_last_record:32-80      0.559792
# 98  mths_since_last_record:81-86      0.222047
# 99    mths_since_last_record:>86      0.283176
#
# [100 rows x 2 columns]

# %%
p_values = reg1.p_values
p_values = np.append(np.nan,np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Out:
#                     Feature name  Coefficients      p_values
# 0                      Intercept     -1.327641           NaN
# 1                        grade:A      1.149766  9.582396e-37
# 2                        grade:B      0.902129  2.504513e-49
# 3                        grade:C      0.704026  1.856280e-35
# 4                        grade:D      0.513864  1.272815e-21
# ..                           ...           ...           ...
# 95   mths_since_last_record:3-20      0.460804  2.806127e-04
# 96  mths_since_last_record:21-31      0.392406  7.490943e-04
# 97  mths_since_last_record:32-80      0.559792  4.803410e-10
# 98  mths_since_last_record:81-86      0.222047  3.609142e-02
# 99    mths_since_last_record:>86      0.283176  1.378396e-03
#
# [100 rows x 3 columns]

# %%
pd.options.display.max_rows = None
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -1.327641            NaN
# 1                               grade:A      1.149766   9.582396e-37
# 2                               grade:B      0.902129   2.504513e-49
# 3                               grade:C      0.704026   1.856280e-35
# 4                               grade:D      0.513864   1.272815e-21
# 5                               grade:E      0.334387   3.612872e-12
# 6                               grade:F      0.143457   4.234393e-03
# 7                    home_ownership:OWN      0.099309   8.120014e-07
# 8               home_ownership:MORTGAGE      0.112069   8.506276e-19
# 9                      addr_state:NM_VA      0.037136   2.469528e-01
# 10                        addr_state:NY      0.058104   1.675177e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.059092   1.088876e-02
# 12                        addr_state:CA      0.061387   3.855785e-03
# 13               addr_state:UT_KY_AZ_NJ      0.078401   1.681785e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.136959   1.313452e-09
# 15            addr_state:RI_MA_DE_SD_IN      0.099198   8.984659e-04
# 16                  addr_state:GA_WA_OR      0.184953   4.400343e-12
# 17                     addr_state:WI_MT      0.247961   1.957971e-07
# 18                        addr_state:TX      0.224577   6.142092e-18
# 19                     addr_state:IL_CT      0.263050   2.497688e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.322870   1.367063e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.514016   3.525404e-22
# 22     verification_status:Not Verified      0.083729   1.215092e-08
# 23  verification_status:Source Verified     -0.014567   2.792053e-01
# 24                  purpose:credit_card      0.306436   4.630683e-27
# 25           purpose:debt_consolidation      0.202895   8.876382e-15
# 26           purpose:oth__med__vacation      0.216092   4.573476e-12
# 27  purpose:major_purch__car__home_impr      0.267588   1.464121e-17
# 28                initial_list_status:w      0.054362   3.137395e-05
# 29                              term:36      0.075843   8.400082e-08
# 30                         emp_length:1      0.091352   4.229386e-04
# 31                       emp_length:2-4      0.115859   7.415815e-10
# 32                       emp_length:5-6      0.081685   1.315202e-04
# 33                       emp_length:7-9      0.055073   8.013516e-03
# 34                        emp_length:10      0.128010   3.455955e-12
# 35               mths_since_issue_d:<38      1.049327  1.350771e-165
# 36             mths_since_issue_d:38-39      0.850526  8.736232e-136
# 37             mths_since_issue_d:40-41      0.751221  3.464308e-111
# 38             mths_since_issue_d:42-48      0.551098   2.074975e-76
# 39             mths_since_issue_d:49-52      0.389779   1.537971e-34
# 40             mths_since_issue_d:53-64      0.146648   9.974830e-07
# 41             mths_since_issue_d:65-84     -0.080742   5.839725e-03
# 42                      int_rate:<9.548      0.873042   2.439368e-30
# 43                int_rate:9.548-12.025      0.550985   1.414585e-34
# 44                int_rate:12.025-15.74      0.298902   5.994239e-16
# 45                int_rate:15.74-20.281      0.107621   2.204235e-04
# 46                        delinq_2yrs:0      0.075310   1.855105e-01
# 47                      delinq_2yrs:1-3      0.036842   4.910119e-01
# 48                     inq_last_6mths:0      0.665895   6.390005e-09
# 49                   inq_last_6mths:1-2      0.521607   5.247269e-06
# 50                   inq_last_6mths:3-6      0.310125   7.008019e-03
# 51                         open_acc:1-3      0.005805   9.718646e-01
# 52                        open_acc:4-12     -0.094879   5.552273e-01
# 53                       open_acc:13-17     -0.123063   4.452180e-01
# 54                       open_acc:18-22     -0.141259   3.839165e-01
# 55                       open_acc:23-25     -0.147655   3.763385e-01
# 56                       open_acc:26-30     -0.111935   5.157055e-01
# 57                        open_acc:>=31     -0.203312   2.747837e-01
# 58                          pub_rec:3-4      0.121918   1.981322e-01
# 59                          pub_rec:>=5      0.178283   3.547276e-01
# 60                      total_acc:28-51     -0.011750   4.034480e-01
# 61                       total_acc:>=52      0.040729   3.045889e-01
# 62                   acc_now_delinq:>=1      0.208816   4.984034e-02
# 63              total_rev_hi_lim:5K-10K      0.043496   7.734029e-02
# 64             total_rev_hi_lim:10K-20K      0.014222   5.509767e-01
# 65             total_rev_hi_lim:20K-30K      0.017077   5.140219e-01
# 66             total_rev_hi_lim:30K-40K      0.037150   2.051931e-01
# 67             total_rev_hi_lim:40K-55K      0.063258   4.797804e-02
# 68             total_rev_hi_lim:55K-95K      0.096240   7.199826e-03
# 69                total_rev_hi_lim:>95K      0.249479   9.489338e-06
# 70                   annual_inc:20K-30K     -0.064604   1.325502e-01
# 71                   annual_inc:30K-40K      0.006224   8.804930e-01
# 72                   annual_inc:40K-50K      0.105504   1.082013e-02
# 73                   annual_inc:50K-60K      0.175889   2.766290e-05
# 74                   annual_inc:60K-70K      0.253015   3.874379e-09
# 75                   annual_inc:70K-80K      0.327598   8.202203e-14
# 76                   annual_inc:80K-90K      0.404250   8.972754e-19
# 77                  annual_inc:90K-100K      0.424117   3.137095e-19
# 78                 annual_inc:100K-120K      0.503605   8.955716e-27
# 79                 annual_inc:120K-140K      0.594747   5.851862e-29
# 80                     annual_inc:>140K      0.523632   3.039437e-26
# 81                            dti:<=1.4      0.203374   2.127908e-02
# 82                          dti:1.4-3.5      0.328934   1.055637e-05
# 83                          dti:3.5-7.7      0.361291   2.888225e-08
# 84                         dti:7.7-10.5      0.303108   2.660390e-06
# 85                        dti:10.5-16.1      0.228245   2.642198e-04
# 86                        dti:16.1-20.3      0.131119   3.602240e-02
# 87                        dti:20.3-21.7      0.121444   6.170918e-02
# 88                        dti:21.7-22.4      0.086882   2.067589e-01
# 89                          dti:22.4-35      0.047617   4.409080e-01
# 90       mths_since_last_delinq:Missing      0.064755   2.595985e-01
# 91          mths_since_last_delinq:4-30      0.142045   7.475954e-03
# 92         mths_since_last_delinq:31-56      0.154911   8.138991e-03
# 93          mths_since_last_delinq:>=57      0.105946   7.586402e-02
# 94       mths_since_last_record:Missing      0.357884   3.057802e-05
# 95          mths_since_last_record:3-20      0.460804   2.806127e-04
# 96         mths_since_last_record:21-31      0.392406   7.490943e-04
# 97         mths_since_last_record:32-80      0.559792   4.803410e-10
# 98         mths_since_last_record:81-86      0.222047   3.609142e-02
# 99           mths_since_last_record:>86      0.283176   1.378396e-03

# %% [markdown]
# Removing the variables that have p value greater than 0.05 because they are not statistically significant. Therefore, we remove delinq_2yrs, open_acc, pub_rec, total_rev_hi_lim, total_acc.

# %%
inputs_train_with_ref_cat = loan_data_inputs_train.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86',
]]

ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_train = inputs_train_with_ref_cat.drop(ref_categories, axis = 1)
inputs_train.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 427211        1        0        0        0        0        0
# 206088        0        0        1        0        0        0
# 136020        1        0        0        0        0        0
# 412305        0        0        0        1        0        0
# 36159         0        0        1        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 427211                   0                        1                 0
# 206088                   0                        1                 0
# 136020                   0                        1                 0
# 412305                   0                        0                 0
# 36159                    0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 427211              0  ...                               1
# 206088              0  ...                               0
# 136020              0  ...                               0
# 412305              0  ...                               0
# 36159               0  ...                               1
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 427211                            0                             0
# 206088                            1                             0
# 136020                            0                             1
# 412305                            1                             0
# 36159                             0                             0
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 427211                            0                               1
# 206088                            0                               1
# 136020                            0                               1
# 412305                            0                               1
# 36159                             0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 427211                            0                             0
# 206088                            0                             0
# 136020                            0                             0
# 412305                            0                             0
# 36159                             0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 427211                             0                             0
# 206088                             0                             0
# 136020                             0                             0
# 412305                             0                             0
# 36159                              0                             0
#
#         mths_since_last_record:>86
# 427211                           0
# 206088                           0
# 136020                           0
# 412305                           0
# 36159                            0
#
# [5 rows x 79 columns]

# %%
reg2 = LogisticRegression_with_p_values()
reg2.fit(inputs_train, loan_data_targets_train)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\Lenovo\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
feature_name = inputs_train.columns.values

# %%
summary_table = pd.DataFrame(columns = ['Feature name'], data = feature_name)
summary_table['Coefficients'] = np.transpose(reg2.coef_)
summary_table.index = summary_table.index + 1
summary_table.loc[0] = ['Intercept', reg2.intercept_[0]]
summary_table = summary_table.sort_index()
summary_table
# Out:
#                            Feature name  Coefficients
# 0                             Intercept     -1.363017
# 1                               grade:A      1.150683
# 2                               grade:B      0.902683
# 3                               grade:C      0.706017
# 4                               grade:D      0.517070
# 5                               grade:E      0.339875
# 6                               grade:F      0.149022
# 7                    home_ownership:OWN      0.103687
# 8               home_ownership:MORTGAGE      0.113136
# 9                      addr_state:NM_VA      0.038315
# 10                        addr_state:NY      0.057726
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.060115
# 12                        addr_state:CA      0.063581
# 13               addr_state:UT_KY_AZ_NJ      0.079940
# 14            addr_state:AR_MI_PA_OH_MN      0.137513
# 15            addr_state:RI_MA_DE_SD_IN      0.101512
# 16                  addr_state:GA_WA_OR      0.187029
# 17                     addr_state:WI_MT      0.249302
# 18                        addr_state:TX      0.223806
# 19                     addr_state:IL_CT      0.263615
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.322896
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.522930
# 22     verification_status:Not Verified      0.080402
# 23  verification_status:Source Verified     -0.015836
# 24                  purpose:credit_card      0.304117
# 25           purpose:debt_consolidation      0.200375
# 26           purpose:oth__med__vacation      0.216068
# 27  purpose:major_purch__car__home_impr      0.265220
# 28                initial_list_status:w      0.054146
# 29                              term:36      0.073198
# 30                         emp_length:1      0.090339
# 31                       emp_length:2-4      0.115451
# 32                       emp_length:5-6      0.081700
# 33                       emp_length:7-9      0.055107
# 34                        emp_length:10      0.130579
# 35               mths_since_issue_d:<38      1.060861
# 36             mths_since_issue_d:38-39      0.858934
# 37             mths_since_issue_d:40-41      0.759594
# 38             mths_since_issue_d:42-48      0.560892
# 39             mths_since_issue_d:49-52      0.399757
# 40             mths_since_issue_d:53-64      0.156001
# 41             mths_since_issue_d:65-84     -0.082105
# 42                      int_rate:<9.548      0.891710
# 43                int_rate:9.548-12.025      0.563528
# 44                int_rate:12.025-15.74      0.308010
# 45                int_rate:15.74-20.281      0.113786
# 46                     inq_last_6mths:0      0.678363
# 47                   inq_last_6mths:1-2      0.531914
# 48                   inq_last_6mths:3-6      0.320662
# 49                   acc_now_delinq:>=1      0.195468
# 50                   annual_inc:20K-30K     -0.070674
# 51                   annual_inc:30K-40K     -0.004288
# 52                   annual_inc:40K-50K      0.093152
# 53                   annual_inc:50K-60K      0.163083
# 54                   annual_inc:60K-70K      0.240573
# 55                   annual_inc:70K-80K      0.316972
# 56                   annual_inc:80K-90K      0.395119
# 57                  annual_inc:90K-100K      0.416305
# 58                 annual_inc:100K-120K      0.498071
# 59                 annual_inc:120K-140K      0.594423
# 60                     annual_inc:>140K      0.534017
# 61                            dti:<=1.4      0.239965
# 62                          dti:1.4-3.5      0.354255
# 63                          dti:3.5-7.7      0.375916
# 64                         dti:7.7-10.5      0.313472
# 65                        dti:10.5-16.1      0.235874
# 66                        dti:16.1-20.3      0.136447
# 67                        dti:20.3-21.7      0.125781
# 68                        dti:21.7-22.4      0.089738
# 69                          dti:22.4-35      0.050562
# 70       mths_since_last_delinq:Missing      0.102752
# 71          mths_since_last_delinq:4-30      0.141855
# 72         mths_since_last_delinq:31-56      0.185661
# 73          mths_since_last_delinq:>=57      0.137300
# 74       mths_since_last_record:Missing      0.336859
# 75          mths_since_last_record:3-20      0.460786
# 76         mths_since_last_record:21-31      0.379282
# 77         mths_since_last_record:32-80      0.537077
# 78         mths_since_last_record:81-86      0.192636
# 79           mths_since_last_record:>86      0.255172

# %%
p_values = reg2.p_values
p_values = np.append(np.nan,np.array(p_values))
summary_table['p_values'] = p_values
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -1.363017            NaN
# 1                               grade:A      1.150683   6.493398e-37
# 2                               grade:B      0.902683   8.562678e-50
# 3                               grade:C      0.706017   4.328151e-36
# 4                               grade:D      0.517070   2.846739e-22
# 5                               grade:E      0.339875   5.407915e-13
# 6                               grade:F      0.149022   2.340250e-03
# 7                    home_ownership:OWN      0.103687   2.427123e-07
# 8               home_ownership:MORTGAGE      0.113136   2.380389e-19
# 9                      addr_state:NM_VA      0.038315   2.316105e-01
# 10                        addr_state:NY      0.057726   1.712761e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.060115   9.382653e-03
# 12                        addr_state:CA      0.063581   2.695528e-03
# 13               addr_state:UT_KY_AZ_NJ      0.079940   1.328778e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.137513   1.001046e-09
# 15            addr_state:RI_MA_DE_SD_IN      0.101512   6.665786e-04
# 16                  addr_state:GA_WA_OR      0.187029   2.294597e-12
# 17                     addr_state:WI_MT      0.249302   1.629901e-07
# 18                        addr_state:TX      0.223806   6.894934e-18
# 19                     addr_state:IL_CT      0.263615   1.750119e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.322896   1.120202e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.522930   8.378406e-23
# 22     verification_status:Not Verified      0.080402   3.500395e-08
# 23  verification_status:Source Verified     -0.015836   2.376157e-01
# 24                  purpose:credit_card      0.304117   5.128792e-27
# 25           purpose:debt_consolidation      0.200375   1.231238e-14
# 26           purpose:oth__med__vacation      0.216068   3.656105e-12
# 27  purpose:major_purch__car__home_impr      0.265220   1.940163e-17
# 28                initial_list_status:w      0.054146   3.365657e-05
# 29                              term:36      0.073198   1.504587e-07
# 30                         emp_length:1      0.090339   4.841712e-04
# 31                       emp_length:2-4      0.115451   8.191726e-10
# 32                       emp_length:5-6      0.081700   1.298719e-04
# 33                       emp_length:7-9      0.055107   7.940178e-03
# 34                        emp_length:10      0.130579   1.196903e-12
# 35               mths_since_issue_d:<38      1.060861  2.492088e-175
# 36             mths_since_issue_d:38-39      0.858934  1.263264e-144
# 37             mths_since_issue_d:40-41      0.759594  2.259928e-119
# 38             mths_since_issue_d:42-48      0.560892   8.393180e-84
# 39             mths_since_issue_d:49-52      0.399757   3.871994e-38
# 40             mths_since_issue_d:53-64      0.156001   8.464982e-08
# 41             mths_since_issue_d:65-84     -0.082105   4.922289e-03
# 42                      int_rate:<9.548      0.891710   9.942819e-32
# 43                int_rate:9.548-12.025      0.563528   1.356033e-36
# 44                int_rate:12.025-15.74      0.308010   4.578890e-17
# 45                int_rate:15.74-20.281      0.113786   8.543059e-05
# 46                     inq_last_6mths:0      0.678363   7.812819e-15
# 47                   inq_last_6mths:1-2      0.531914   1.055744e-09
# 48                   inq_last_6mths:3-6      0.320662   2.579841e-04
# 49                   acc_now_delinq:>=1      0.195468   6.505953e-02
# 50                   annual_inc:20K-30K     -0.070674   9.224062e-02
# 51                   annual_inc:30K-40K     -0.004288   9.151110e-01
# 52                   annual_inc:40K-50K      0.093152   2.015477e-02
# 53                   annual_inc:50K-60K      0.163083   5.789103e-05
# 54                   annual_inc:60K-70K      0.240573   6.471118e-09
# 55                   annual_inc:70K-80K      0.316972   6.440899e-14
# 56                   annual_inc:80K-90K      0.395119   2.871908e-19
# 57                  annual_inc:90K-100K      0.416305   7.099694e-20
# 58                 annual_inc:100K-120K      0.498071   2.925291e-28
# 59                 annual_inc:120K-140K      0.594423   7.642023e-31
# 60                     annual_inc:>140K      0.534017   5.887430e-30
# 61                            dti:<=1.4      0.239965   3.939726e-03
# 62                          dti:1.4-3.5      0.354255   3.835659e-07
# 63                          dti:3.5-7.7      0.375916   3.912500e-10
# 64                         dti:7.7-10.5      0.313472   1.516656e-07
# 65                        dti:10.5-16.1      0.235874   4.326273e-05
# 66                        dti:16.1-20.3      0.136447   1.816938e-02
# 67                        dti:20.3-21.7      0.125781   3.754793e-02
# 68                        dti:21.7-22.4      0.089738   1.645268e-01
# 69                          dti:22.4-35      0.050562   3.756922e-01
# 70       mths_since_last_delinq:Missing      0.102752   4.846849e-02
# 71          mths_since_last_delinq:4-30      0.141855   7.020200e-03
# 72         mths_since_last_delinq:31-56      0.185661   4.946431e-04
# 73          mths_since_last_delinq:>=57      0.137300   1.185531e-02
# 74       mths_since_last_record:Missing      0.336859   3.167814e-05
# 75          mths_since_last_record:3-20      0.460786   1.678724e-04
# 76         mths_since_last_record:21-31      0.379282   7.240039e-04
# 77         mths_since_last_record:32-80      0.537077   2.603883e-10
# 78         mths_since_last_record:81-86      0.192636   5.872193e-02
# 79           mths_since_last_record:>86      0.255172   2.315476e-03

# %%
pickle.dump(reg2, open('pd_model.sav', 'wb'))
# Here we export our model to a 'SAV' file with file name 'pd_model.sav'.

# %% [markdown]
# ## Testing

# %%
inputs_test_with_ref_cat = loan_data_inputs_test.loc[: , ['grade:A',
'grade:B',
'grade:C',
'grade:D',
'grade:E',
'grade:F',
'grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'home_ownership:OWN',
'home_ownership:MORTGAGE',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'addr_state:NM_VA',
'addr_state:NY',
'addr_state:OK_TN_MO_LA_MD_NC',
'addr_state:CA',
'addr_state:UT_KY_AZ_NJ',
'addr_state:AR_MI_PA_OH_MN',
'addr_state:RI_MA_DE_SD_IN',
'addr_state:GA_WA_OR',
'addr_state:WI_MT',
'addr_state:TX',
'addr_state:IL_CT',
'addr_state:KS_SC_CO_VT_AK_MS',
'addr_state:WV_NH_WY_DC_ME_ID',
'verification_status:Not Verified',
'verification_status:Source Verified',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'purpose:credit_card',
'purpose:debt_consolidation',
'purpose:oth__med__vacation',
'purpose:major_purch__car__home_impr',
'initial_list_status:f',
'initial_list_status:w',
'term:36',
'term:60',
'emp_length:0',
'emp_length:1',
'emp_length:2-4',
'emp_length:5-6',
'emp_length:7-9',
'emp_length:10',
'mths_since_issue_d:<38',
'mths_since_issue_d:38-39',
'mths_since_issue_d:40-41',
'mths_since_issue_d:42-48',
'mths_since_issue_d:49-52',
'mths_since_issue_d:53-64',
'mths_since_issue_d:65-84',
'mths_since_issue_d:>84',
'int_rate:<9.548',
'int_rate:9.548-12.025',
'int_rate:12.025-15.74',
'int_rate:15.74-20.281',
'int_rate:>20.281',
'inq_last_6mths:0',
'inq_last_6mths:1-2',
'inq_last_6mths:3-6',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'acc_now_delinq:>=1',
'annual_inc:<20K',
'annual_inc:20K-30K',
'annual_inc:30K-40K',
'annual_inc:40K-50K',
'annual_inc:50K-60K',
'annual_inc:60K-70K',
'annual_inc:70K-80K',
'annual_inc:80K-90K',
'annual_inc:90K-100K',
'annual_inc:100K-120K',
'annual_inc:120K-140K',
'annual_inc:>140K',
'dti:<=1.4',
'dti:1.4-3.5',
'dti:3.5-7.7',
'dti:7.7-10.5',
'dti:10.5-16.1',
'dti:16.1-20.3',
'dti:20.3-21.7',
'dti:21.7-22.4',
'dti:22.4-35',
'dti:>35',
'mths_since_last_delinq:Missing',
'mths_since_last_delinq:0-3',
'mths_since_last_delinq:4-30',
'mths_since_last_delinq:31-56',
'mths_since_last_delinq:>=57',
'mths_since_last_record:Missing',
'mths_since_last_record:0-2',
'mths_since_last_record:3-20',
'mths_since_last_record:21-31',
'mths_since_last_record:32-80',
'mths_since_last_record:81-86',
'mths_since_last_record:>86',
]]

# %%
ref_categories = ['grade:G',
'home_ownership:RENT_OTHER_NONE_ANY',
'addr_state:ND_NE_IA_NV_FL_HI_AL',
'verification_status:Verified',
'purpose:educ__sm_b__wedd__ren_en__mov__house',
'initial_list_status:f',
'term:60',
'emp_length:0',
'mths_since_issue_d:>84',
'int_rate:>20.281',
'inq_last_6mths:>6',
'acc_now_delinq:0',
'annual_inc:<20K',
'dti:>35',
'mths_since_last_delinq:0-3',
'mths_since_last_record:0-2']

# %%
inputs_test = inputs_test_with_ref_cat.drop(ref_categories, axis = 1)
inputs_test.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514        0        0        1        0        0        0
# 288564        0        0        0        0        1        0
# 213591        0        0        1        0        0        0
# 263083        0        0        1        0        0        0
# 165001        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  ...  mths_since_last_delinq:Missing  \
# 362514              0  ...                               1
# 288564              0  ...                               0
# 213591              0  ...                               0
# 263083              0  ...                               1
# 165001              0  ...                               0
#
#         mths_since_last_delinq:4-30  mths_since_last_delinq:31-56  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             1
# 263083                            0                             0
# 165001                            0                             1
#
#         mths_since_last_delinq:>=57  mths_since_last_record:Missing  \
# 362514                            0                               1
# 288564                            0                               1
# 213591                            0                               1
# 263083                            0                               1
# 165001                            0                               1
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>86
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0
#
# [5 rows x 79 columns]

# %%
y_pred = reg2.model.predict(inputs_test)

# %%
y_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int64)

# %%
print(accuracy_score(loan_data_targets_test,y_pred))
# Out:
# 0.8907427860643169

# %%
y_hat_test_proba = reg2.model.predict_proba(inputs_test)
y_hat_test_proba
#[prob of bad, prob of good]
# Out:
# array([[0.07415428, 0.92584572],
#        [0.14577287, 0.85422713],
#        [0.10942134, 0.89057866],
#        ...,
#        [0.02683008, 0.97316992],
#        [0.04237822, 0.95762178],
#        [0.04662264, 0.95337736]])

# %%
y_hat_test_proba[:][:,1]
# Out:
# array([0.92584572, 0.85422713, 0.89057866, ..., 0.97316992, 0.95762178,
#        0.95337736])

# %%
y_hat_test_proba = y_hat_test_proba[: ][: , 1]

# %%
loan_data_targets_test_temp = loan_data_targets_test

# %%
loan_data_targets_test_temp.reset_index(drop = True, inplace = True)

# %%
df_actual_predicted_probs = pd.concat([loan_data_targets_test_temp, pd.DataFrame(y_hat_test_proba)], axis = 1)

# %%
df_actual_predicted_probs.shape
# Out:
# (93257, 2)

# %%
df_actual_predicted_probs.columns = ['loan_data_targets_test', 'y_hat_test_proba']

# %%
df_actual_predicted_probs.index = loan_data_inputs_test.index
# Makes the index of one dataframe equal to the index of another dataframe.

# %%
df_actual_predicted_probs.head()
# Out:
#         loan_data_targets_test  y_hat_test_proba
# 362514                       1          0.925846
# 288564                       1          0.854227
# 213591                       1          0.890579
# 263083                       1          0.943302
# 165001                       1          0.967694

# %% [markdown]
# ### Accuracy and Area under the Curve

# %%
tr = 0.9
# create a new column with an indicator,
# where every observation that has predicted probability greater than the threshold has a value of 1,
# and every observation that has predicted probability lower than the threshold has a value of 0.
df_actual_predicted_probs['y_hat_test'] = np.where(df_actual_predicted_probs['y_hat_test_proba'] > tr, 1, 0)

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted'])
# Creates a cross-table where the actual values are displayed by rows and the predicted values by columns.
# This table is known as a Confusion Matrix.
# Out:
# Predicted      0      1
# Actual
# 0           7379   2811
# 1          35847  47220

# %%
pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]
# Out:
# Predicted         0         1
# Actual
# 0          0.079125  0.030143
# 1          0.384389  0.506343

# %%
(pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[0, 0] + (pd.crosstab(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test'], rownames = ['Actual'], colnames = ['Predicted']) / df_actual_predicted_probs.shape[0]).iloc[1, 1]
# calculate Accuracy of the model, which is the sum of the diagonal rates.
# Out:
# 0.5854681149940487

# %%
roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Returns the Receiver Operating Characteristic (ROC) Curve from a set of actual values and their predicted probabilities.
# As a result, we get three arrays: the false positive rates, the true positive rates, and the thresholds.
# Out:
# (array([0.        , 0.        , 0.        , ..., 0.99960746, 1.        ,
#         1.        ]),
#  array([0.00000000e+00, 1.20384750e-05, 1.68538650e-04, ...,
#         9.99975923e-01, 9.99975923e-01, 1.00000000e+00]),
#  array([1.99247949, 0.99247949, 0.99031188, ..., 0.48389047, 0.39413521,
#         0.37210768]))

# %%
fpr, tpr, thresholds = roc_curve(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Here we store each of the three arrays in a separate variable.

# %%
plt.plot(fpr, tpr)
plt.plot(fpr, fpr, linestyle = '--', color = 'k')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
# Out:
# Text(0.5, 1.0, 'ROC curve')

# %%
AUROC = roc_auc_score(df_actual_predicted_probs['loan_data_targets_test'], df_actual_predicted_probs['y_hat_test_proba'])
# Calculates the Area Under the Receiver Operating Characteristic Curve (AUROC)
# from a set of actual values and their predicted probabilities.
AUROC
# Out:
# 0.7020470008998613

# %% [markdown]
# # Credit score

# %%
pd.options.display.max_columns = None

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  inq_last_6mths:0  inq_last_6mths:1-2  \
# 362514                 0                 1                   0
# 288564                 1                 1                   0
# 213591                 0                 1                   0
# 263083                 0                 1                   0
# 165001                 0                 1                   0
#
#         inq_last_6mths:3-6  inq_last_6mths:>6  acc_now_delinq:0  \
# 362514                   0                  0                 1
# 288564                   0                  0                 1
# 213591                   0                  0                 1
# 263083                   0                  0                 1
# 165001                   0                  0                 1
#
#         acc_now_delinq:>=1  annual_inc:<20K  annual_inc:20K-30K  \
# 362514                   0                0                   0
# 288564                   0                0                   0
# 213591                   0                0                   0
# 263083                   0                0                   0
# 165001                   0                0                   0
#
#         annual_inc:30K-40K  annual_inc:40K-50K  annual_inc:50K-60K  \
# 362514                   0                   0                   0
# 288564                   0                   0                   1
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:60K-70K  annual_inc:70K-80K  annual_inc:80K-90K  \
# 362514                   1                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   1                   0                   0
# 165001                   0                   0                   1
#
#         annual_inc:90K-100K  annual_inc:100K-120K  annual_inc:120K-140K  \
# 362514                    0                     0                     0
# 288564                    0                     0                     0
# 213591                    0                     0                     0
# 263083                    0                     0                     0
# 165001                    0                     0                     0
#
#         annual_inc:>140K  dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  \
# 362514                 0          0            0            0             1
# 288564                 0          0            0            0             0
# 213591                 1          0            0            0             0
# 263083                 0          0            0            0             0
# 165001                 0          0            0            0             1
#
#         dti:10.5-16.1  dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  \
# 362514              0              0              0              0
# 288564              0              0              0              0
# 213591              1              0              0              0
# 263083              0              1              0              0
# 165001              0              0              0              0
#
#         dti:22.4-35  dti:>35  mths_since_last_delinq:Missing  \
# 362514            0        0                               1
# 288564            1        0                               0
# 213591            0        0                               0
# 263083            0        0                               1
# 165001            0        0                               0
#
#         mths_since_last_delinq:0-3  mths_since_last_delinq:4-30  \
# 362514                           0                            0
# 288564                           1                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:0-2  \
# 362514                               1                           0
# 288564                               1                           0
# 213591                               1                           0
# 263083                               1                           0
# 165001                               1                           0
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>86
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0

# %%
summary_table
# Out:
#                            Feature name  Coefficients       p_values
# 0                             Intercept     -1.363017            NaN
# 1                               grade:A      1.150683   6.493398e-37
# 2                               grade:B      0.902683   8.562678e-50
# 3                               grade:C      0.706017   4.328151e-36
# 4                               grade:D      0.517070   2.846739e-22
# 5                               grade:E      0.339875   5.407915e-13
# 6                               grade:F      0.149022   2.340250e-03
# 7                    home_ownership:OWN      0.103687   2.427123e-07
# 8               home_ownership:MORTGAGE      0.113136   2.380389e-19
# 9                      addr_state:NM_VA      0.038315   2.316105e-01
# 10                        addr_state:NY      0.057726   1.712761e-02
# 11         addr_state:OK_TN_MO_LA_MD_NC      0.060115   9.382653e-03
# 12                        addr_state:CA      0.063581   2.695528e-03
# 13               addr_state:UT_KY_AZ_NJ      0.079940   1.328778e-03
# 14            addr_state:AR_MI_PA_OH_MN      0.137513   1.001046e-09
# 15            addr_state:RI_MA_DE_SD_IN      0.101512   6.665786e-04
# 16                  addr_state:GA_WA_OR      0.187029   2.294597e-12
# 17                     addr_state:WI_MT      0.249302   1.629901e-07
# 18                        addr_state:TX      0.223806   6.894934e-18
# 19                     addr_state:IL_CT      0.263615   1.750119e-19
# 20         addr_state:KS_SC_CO_VT_AK_MS      0.322896   1.120202e-25
# 21         addr_state:WV_NH_WY_DC_ME_ID      0.522930   8.378406e-23
# 22     verification_status:Not Verified      0.080402   3.500395e-08
# 23  verification_status:Source Verified     -0.015836   2.376157e-01
# 24                  purpose:credit_card      0.304117   5.128792e-27
# 25           purpose:debt_consolidation      0.200375   1.231238e-14
# 26           purpose:oth__med__vacation      0.216068   3.656105e-12
# 27  purpose:major_purch__car__home_impr      0.265220   1.940163e-17
# 28                initial_list_status:w      0.054146   3.365657e-05
# 29                              term:36      0.073198   1.504587e-07
# 30                         emp_length:1      0.090339   4.841712e-04
# 31                       emp_length:2-4      0.115451   8.191726e-10
# 32                       emp_length:5-6      0.081700   1.298719e-04
# 33                       emp_length:7-9      0.055107   7.940178e-03
# 34                        emp_length:10      0.130579   1.196903e-12
# 35               mths_since_issue_d:<38      1.060861  2.492088e-175
# 36             mths_since_issue_d:38-39      0.858934  1.263264e-144
# 37             mths_since_issue_d:40-41      0.759594  2.259928e-119
# 38             mths_since_issue_d:42-48      0.560892   8.393180e-84
# 39             mths_since_issue_d:49-52      0.399757   3.871994e-38
# 40             mths_since_issue_d:53-64      0.156001   8.464982e-08
# 41             mths_since_issue_d:65-84     -0.082105   4.922289e-03
# 42                      int_rate:<9.548      0.891710   9.942819e-32
# 43                int_rate:9.548-12.025      0.563528   1.356033e-36
# 44                int_rate:12.025-15.74      0.308010   4.578890e-17
# 45                int_rate:15.74-20.281      0.113786   8.543059e-05
# 46                     inq_last_6mths:0      0.678363   7.812819e-15
# 47                   inq_last_6mths:1-2      0.531914   1.055744e-09
# 48                   inq_last_6mths:3-6      0.320662   2.579841e-04
# 49                   acc_now_delinq:>=1      0.195468   6.505953e-02
# 50                   annual_inc:20K-30K     -0.070674   9.224062e-02
# 51                   annual_inc:30K-40K     -0.004288   9.151110e-01
# 52                   annual_inc:40K-50K      0.093152   2.015477e-02
# 53                   annual_inc:50K-60K      0.163083   5.789103e-05
# 54                   annual_inc:60K-70K      0.240573   6.471118e-09
# 55                   annual_inc:70K-80K      0.316972   6.440899e-14
# 56                   annual_inc:80K-90K      0.395119   2.871908e-19
# 57                  annual_inc:90K-100K      0.416305   7.099694e-20
# 58                 annual_inc:100K-120K      0.498071   2.925291e-28
# 59                 annual_inc:120K-140K      0.594423   7.642023e-31
# 60                     annual_inc:>140K      0.534017   5.887430e-30
# 61                            dti:<=1.4      0.239965   3.939726e-03
# 62                          dti:1.4-3.5      0.354255   3.835659e-07
# 63                          dti:3.5-7.7      0.375916   3.912500e-10
# 64                         dti:7.7-10.5      0.313472   1.516656e-07
# 65                        dti:10.5-16.1      0.235874   4.326273e-05
# 66                        dti:16.1-20.3      0.136447   1.816938e-02
# 67                        dti:20.3-21.7      0.125781   3.754793e-02
# 68                        dti:21.7-22.4      0.089738   1.645268e-01
# 69                          dti:22.4-35      0.050562   3.756922e-01
# 70       mths_since_last_delinq:Missing      0.102752   4.846849e-02
# 71          mths_since_last_delinq:4-30      0.141855   7.020200e-03
# 72         mths_since_last_delinq:31-56      0.185661   4.946431e-04
# 73          mths_since_last_delinq:>=57      0.137300   1.185531e-02
# 74       mths_since_last_record:Missing      0.336859   3.167814e-05
# 75          mths_since_last_record:3-20      0.460786   1.678724e-04
# 76         mths_since_last_record:21-31      0.379282   7.240039e-04
# 77         mths_since_last_record:32-80      0.537077   2.603883e-10
# 78         mths_since_last_record:81-86      0.192636   5.872193e-02
# 79           mths_since_last_record:>86      0.255172   2.315476e-03

# %%
y_hat_test_proba
# Out:
# array([0.92584572, 0.85422713, 0.89057866, ..., 0.97316992, 0.95762178,
#        0.95337736])

# %%
ref_categories
# Out:
# ['grade:G',
#  'home_ownership:RENT_OTHER_NONE_ANY',
#  'addr_state:ND_NE_IA_NV_FL_HI_AL',
#  'verification_status:Verified',
#  'purpose:educ__sm_b__wedd__ren_en__mov__house',
#  'initial_list_status:f',
#  'term:60',
#  'emp_length:0',
#  'mths_since_issue_d:>84',
#  'int_rate:>20.281',
#  'inq_last_6mths:>6',
#  'acc_now_delinq:0',
#  'annual_inc:<20K',
#  'dti:>35',
#  'mths_since_last_delinq:0-3',
#  'mths_since_last_record:0-2']

# %%
#Assigning the values of reference categories for coeff and p value as 0 and Nan
df_ref_categories = pd.DataFrame(ref_categories, columns = ['Feature name'])
df_ref_categories['Coefficients'] = 0
df_ref_categories['p_values'] = np.nan
df_ref_categories
# Out:
#                                     Feature name  Coefficients  p_values
# 0                                        grade:G             0       NaN
# 1             home_ownership:RENT_OTHER_NONE_ANY             0       NaN
# 2                addr_state:ND_NE_IA_NV_FL_HI_AL             0       NaN
# 3                   verification_status:Verified             0       NaN
# 4   purpose:educ__sm_b__wedd__ren_en__mov__house             0       NaN
# 5                          initial_list_status:f             0       NaN
# 6                                        term:60             0       NaN
# 7                                   emp_length:0             0       NaN
# 8                         mths_since_issue_d:>84             0       NaN
# 9                               int_rate:>20.281             0       NaN
# 10                             inq_last_6mths:>6             0       NaN
# 11                              acc_now_delinq:0             0       NaN
# 12                               annual_inc:<20K             0       NaN
# 13                                       dti:>35             0       NaN
# 14                    mths_since_last_delinq:0-3             0       NaN
# 15                    mths_since_last_record:0-2             0       NaN

# %%
#concatinating ref categories to summary table of all categories
df_scorecard = pd.concat([summary_table, df_ref_categories])
df_scorecard = df_scorecard.reset_index()
df_scorecard
# Out:
#     index                                  Feature name  Coefficients  \
# 0       0                                     Intercept     -1.363017
# 1       1                                       grade:A      1.150683
# 2       2                                       grade:B      0.902683
# 3       3                                       grade:C      0.706017
# 4       4                                       grade:D      0.517070
# 5       5                                       grade:E      0.339875
# 6       6                                       grade:F      0.149022
# 7       7                            home_ownership:OWN      0.103687
# 8       8                       home_ownership:MORTGAGE      0.113136
# 9       9                              addr_state:NM_VA      0.038315
# 10     10                                 addr_state:NY      0.057726
# 11     11                  addr_state:OK_TN_MO_LA_MD_NC      0.060115
# 12     12                                 addr_state:CA      0.063581
# 13     13                        addr_state:UT_KY_AZ_NJ      0.079940
# 14     14                     addr_state:AR_MI_PA_OH_MN      0.137513
# 15     15                     addr_state:RI_MA_DE_SD_IN      0.101512
# 16     16                           addr_state:GA_WA_OR      0.187029
# 17     17                              addr_state:WI_MT      0.249302
# 18     18                                 addr_state:TX      0.223806
# 19     19                              addr_state:IL_CT      0.263615
# 20     20                  addr_state:KS_SC_CO_VT_AK_MS      0.322896
# 21     21                  addr_state:WV_NH_WY_DC_ME_ID      0.522930
# 22     22              verification_status:Not Verified      0.080402
# 23     23           verification_status:Source Verified     -0.015836
# 24     24                           purpose:credit_card      0.304117
# 25     25                    purpose:debt_consolidation      0.200375
# 26     26                    purpose:oth__med__vacation      0.216068
# 27     27           purpose:major_purch__car__home_impr      0.265220
# 28     28                         initial_list_status:w      0.054146
# 29     29                                       term:36      0.073198
# 30     30                                  emp_length:1      0.090339
# 31     31                                emp_length:2-4      0.115451
# 32     32                                emp_length:5-6      0.081700
# 33     33                                emp_length:7-9      0.055107
# 34     34                                 emp_length:10      0.130579
# 35     35                        mths_since_issue_d:<38      1.060861
# 36     36                      mths_since_issue_d:38-39      0.858934
# 37     37                      mths_since_issue_d:40-41      0.759594
# 38     38                      mths_since_issue_d:42-48      0.560892
# 39     39                      mths_since_issue_d:49-52      0.399757
# 40     40                      mths_since_issue_d:53-64      0.156001
# 41     41                      mths_since_issue_d:65-84     -0.082105
# 42     42                               int_rate:<9.548      0.891710
# 43     43                         int_rate:9.548-12.025      0.563528
# 44     44                         int_rate:12.025-15.74      0.308010
# 45     45                         int_rate:15.74-20.281      0.113786
# 46     46                              inq_last_6mths:0      0.678363
# 47     47                            inq_last_6mths:1-2      0.531914
# 48     48                            inq_last_6mths:3-6      0.320662
# 49     49                            acc_now_delinq:>=1      0.195468
# 50     50                            annual_inc:20K-30K     -0.070674
# 51     51                            annual_inc:30K-40K     -0.004288
# 52     52                            annual_inc:40K-50K      0.093152
# 53     53                            annual_inc:50K-60K      0.163083
# 54     54                            annual_inc:60K-70K      0.240573
# 55     55                            annual_inc:70K-80K      0.316972
# 56     56                            annual_inc:80K-90K      0.395119
# 57     57                           annual_inc:90K-100K      0.416305
# 58     58                          annual_inc:100K-120K      0.498071
# 59     59                          annual_inc:120K-140K      0.594423
# 60     60                              annual_inc:>140K      0.534017
# 61     61                                     dti:<=1.4      0.239965
# 62     62                                   dti:1.4-3.5      0.354255
# 63     63                                   dti:3.5-7.7      0.375916
# 64     64                                  dti:7.7-10.5      0.313472
# 65     65                                 dti:10.5-16.1      0.235874
# 66     66                                 dti:16.1-20.3      0.136447
# 67     67                                 dti:20.3-21.7      0.125781
# 68     68                                 dti:21.7-22.4      0.089738
# 69     69                                   dti:22.4-35      0.050562
# 70     70                mths_since_last_delinq:Missing      0.102752
# 71     71                   mths_since_last_delinq:4-30      0.141855
# 72     72                  mths_since_last_delinq:31-56      0.185661
# 73     73                   mths_since_last_delinq:>=57      0.137300
# 74     74                mths_since_last_record:Missing      0.336859
# 75     75                   mths_since_last_record:3-20      0.460786
# 76     76                  mths_since_last_record:21-31      0.379282
# 77     77                  mths_since_last_record:32-80      0.537077
# 78     78                  mths_since_last_record:81-86      0.192636
# 79     79                    mths_since_last_record:>86      0.255172
# 80      0                                       grade:G      0.000000
# 81      1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 82      2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 83      3                  verification_status:Verified      0.000000
# 84      4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 85      5                         initial_list_status:f      0.000000
# 86      6                                       term:60      0.000000
# 87      7                                  emp_length:0      0.000000
# 88      8                        mths_since_issue_d:>84      0.000000
# 89      9                              int_rate:>20.281      0.000000
# 90     10                             inq_last_6mths:>6      0.000000
# 91     11                              acc_now_delinq:0      0.000000
# 92     12                               annual_inc:<20K      0.000000
# 93     13                                       dti:>35      0.000000
# 94     14                    mths_since_last_delinq:0-3      0.000000
# 95     15                    mths_since_last_record:0-2      0.000000
#
#          p_values
# 0             NaN
# 1    6.493398e-37
# 2    8.562678e-50
# 3    4.328151e-36
# 4    2.846739e-22
# 5    5.407915e-13
# 6    2.340250e-03
# 7    2.427123e-07
# 8    2.380389e-19
# 9    2.316105e-01
# 10   1.712761e-02
# 11   9.382653e-03
# 12   2.695528e-03
# 13   1.328778e-03
# 14   1.001046e-09
# 15   6.665786e-04
# 16   2.294597e-12
# 17   1.629901e-07
# 18   6.894934e-18
# 19   1.750119e-19
# 20   1.120202e-25
# 21   8.378406e-23
# 22   3.500395e-08
# 23   2.376157e-01
# 24   5.128792e-27
# 25   1.231238e-14
# 26   3.656105e-12
# 27   1.940163e-17
# 28   3.365657e-05
# 29   1.504587e-07
# 30   4.841712e-04
# 31   8.191726e-10
# 32   1.298719e-04
# 33   7.940178e-03
# 34   1.196903e-12
# 35  2.492088e-175
# 36  1.263264e-144
# 37  2.259928e-119
# 38   8.393180e-84
# 39   3.871994e-38
# 40   8.464982e-08
# 41   4.922289e-03
# 42   9.942819e-32
# 43   1.356033e-36
# 44   4.578890e-17
# 45   8.543059e-05
# 46   7.812819e-15
# 47   1.055744e-09
# 48   2.579841e-04
# 49   6.505953e-02
# 50   9.224062e-02
# 51   9.151110e-01
# 52   2.015477e-02
# 53   5.789103e-05
# 54   6.471118e-09
# 55   6.440899e-14
# 56   2.871908e-19
# 57   7.099694e-20
# 58   2.925291e-28
# 59   7.642023e-31
# 60   5.887430e-30
# 61   3.939726e-03
# 62   3.835659e-07
# 63   3.912500e-10
# 64   1.516656e-07
# 65   4.326273e-05
# 66   1.816938e-02
# 67   3.754793e-02
# 68   1.645268e-01
# 69   3.756922e-01
# 70   4.846849e-02
# 71   7.020200e-03
# 72   4.946431e-04
# 73   1.185531e-02
# 74   3.167814e-05
# 75   1.678724e-04
# 76   7.240039e-04
# 77   2.603883e-10
# 78   5.872193e-02
# 79   2.315476e-03
# 80            NaN
# 81            NaN
# 82            NaN
# 83            NaN
# 84            NaN
# 85            NaN
# 86            NaN
# 87            NaN
# 88            NaN
# 89            NaN
# 90            NaN
# 91            NaN
# 92            NaN
# 93            NaN
# 94            NaN
# 95            NaN

# %%
df_scorecard['Original feature name'] = df_scorecard['Feature name'].str.split(':').str[0]
df_scorecard
# Out:
#     index                                  Feature name  Coefficients  \
# 0       0                                     Intercept     -1.363017
# 1       1                                       grade:A      1.150683
# 2       2                                       grade:B      0.902683
# 3       3                                       grade:C      0.706017
# 4       4                                       grade:D      0.517070
# 5       5                                       grade:E      0.339875
# 6       6                                       grade:F      0.149022
# 7       7                            home_ownership:OWN      0.103687
# 8       8                       home_ownership:MORTGAGE      0.113136
# 9       9                              addr_state:NM_VA      0.038315
# 10     10                                 addr_state:NY      0.057726
# 11     11                  addr_state:OK_TN_MO_LA_MD_NC      0.060115
# 12     12                                 addr_state:CA      0.063581
# 13     13                        addr_state:UT_KY_AZ_NJ      0.079940
# 14     14                     addr_state:AR_MI_PA_OH_MN      0.137513
# 15     15                     addr_state:RI_MA_DE_SD_IN      0.101512
# 16     16                           addr_state:GA_WA_OR      0.187029
# 17     17                              addr_state:WI_MT      0.249302
# 18     18                                 addr_state:TX      0.223806
# 19     19                              addr_state:IL_CT      0.263615
# 20     20                  addr_state:KS_SC_CO_VT_AK_MS      0.322896
# 21     21                  addr_state:WV_NH_WY_DC_ME_ID      0.522930
# 22     22              verification_status:Not Verified      0.080402
# 23     23           verification_status:Source Verified     -0.015836
# 24     24                           purpose:credit_card      0.304117
# 25     25                    purpose:debt_consolidation      0.200375
# 26     26                    purpose:oth__med__vacation      0.216068
# 27     27           purpose:major_purch__car__home_impr      0.265220
# 28     28                         initial_list_status:w      0.054146
# 29     29                                       term:36      0.073198
# 30     30                                  emp_length:1      0.090339
# 31     31                                emp_length:2-4      0.115451
# 32     32                                emp_length:5-6      0.081700
# 33     33                                emp_length:7-9      0.055107
# 34     34                                 emp_length:10      0.130579
# 35     35                        mths_since_issue_d:<38      1.060861
# 36     36                      mths_since_issue_d:38-39      0.858934
# 37     37                      mths_since_issue_d:40-41      0.759594
# 38     38                      mths_since_issue_d:42-48      0.560892
# 39     39                      mths_since_issue_d:49-52      0.399757
# 40     40                      mths_since_issue_d:53-64      0.156001
# 41     41                      mths_since_issue_d:65-84     -0.082105
# 42     42                               int_rate:<9.548      0.891710
# 43     43                         int_rate:9.548-12.025      0.563528
# 44     44                         int_rate:12.025-15.74      0.308010
# 45     45                         int_rate:15.74-20.281      0.113786
# 46     46                              inq_last_6mths:0      0.678363
# 47     47                            inq_last_6mths:1-2      0.531914
# 48     48                            inq_last_6mths:3-6      0.320662
# 49     49                            acc_now_delinq:>=1      0.195468
# 50     50                            annual_inc:20K-30K     -0.070674
# 51     51                            annual_inc:30K-40K     -0.004288
# 52     52                            annual_inc:40K-50K      0.093152
# 53     53                            annual_inc:50K-60K      0.163083
# 54     54                            annual_inc:60K-70K      0.240573
# 55     55                            annual_inc:70K-80K      0.316972
# 56     56                            annual_inc:80K-90K      0.395119
# 57     57                           annual_inc:90K-100K      0.416305
# 58     58                          annual_inc:100K-120K      0.498071
# 59     59                          annual_inc:120K-140K      0.594423
# 60     60                              annual_inc:>140K      0.534017
# 61     61                                     dti:<=1.4      0.239965
# 62     62                                   dti:1.4-3.5      0.354255
# 63     63                                   dti:3.5-7.7      0.375916
# 64     64                                  dti:7.7-10.5      0.313472
# 65     65                                 dti:10.5-16.1      0.235874
# 66     66                                 dti:16.1-20.3      0.136447
# 67     67                                 dti:20.3-21.7      0.125781
# 68     68                                 dti:21.7-22.4      0.089738
# 69     69                                   dti:22.4-35      0.050562
# 70     70                mths_since_last_delinq:Missing      0.102752
# 71     71                   mths_since_last_delinq:4-30      0.141855
# 72     72                  mths_since_last_delinq:31-56      0.185661
# 73     73                   mths_since_last_delinq:>=57      0.137300
# 74     74                mths_since_last_record:Missing      0.336859
# 75     75                   mths_since_last_record:3-20      0.460786
# 76     76                  mths_since_last_record:21-31      0.379282
# 77     77                  mths_since_last_record:32-80      0.537077
# 78     78                  mths_since_last_record:81-86      0.192636
# 79     79                    mths_since_last_record:>86      0.255172
# 80      0                                       grade:G      0.000000
# 81      1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 82      2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 83      3                  verification_status:Verified      0.000000
# 84      4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 85      5                         initial_list_status:f      0.000000
# 86      6                                       term:60      0.000000
# 87      7                                  emp_length:0      0.000000
# 88      8                        mths_since_issue_d:>84      0.000000
# 89      9                              int_rate:>20.281      0.000000
# 90     10                             inq_last_6mths:>6      0.000000
# 91     11                              acc_now_delinq:0      0.000000
# 92     12                               annual_inc:<20K      0.000000
# 93     13                                       dti:>35      0.000000
# 94     14                    mths_since_last_delinq:0-3      0.000000
# 95     15                    mths_since_last_record:0-2      0.000000
#
#          p_values   Original feature name
# 0             NaN               Intercept
# 1    6.493398e-37                   grade
# 2    8.562678e-50                   grade
# 3    4.328151e-36                   grade
# 4    2.846739e-22                   grade
# 5    5.407915e-13                   grade
# 6    2.340250e-03                   grade
# 7    2.427123e-07          home_ownership
# 8    2.380389e-19          home_ownership
# 9    2.316105e-01              addr_state
# 10   1.712761e-02              addr_state
# 11   9.382653e-03              addr_state
# 12   2.695528e-03              addr_state
# 13   1.328778e-03              addr_state
# 14   1.001046e-09              addr_state
# 15   6.665786e-04              addr_state
# 16   2.294597e-12              addr_state
# 17   1.629901e-07              addr_state
# 18   6.894934e-18              addr_state
# 19   1.750119e-19              addr_state
# 20   1.120202e-25              addr_state
# 21   8.378406e-23              addr_state
# 22   3.500395e-08     verification_status
# 23   2.376157e-01     verification_status
# 24   5.128792e-27                 purpose
# 25   1.231238e-14                 purpose
# 26   3.656105e-12                 purpose
# 27   1.940163e-17                 purpose
# 28   3.365657e-05     initial_list_status
# 29   1.504587e-07                    term
# 30   4.841712e-04              emp_length
# 31   8.191726e-10              emp_length
# 32   1.298719e-04              emp_length
# 33   7.940178e-03              emp_length
# 34   1.196903e-12              emp_length
# 35  2.492088e-175      mths_since_issue_d
# 36  1.263264e-144      mths_since_issue_d
# 37  2.259928e-119      mths_since_issue_d
# 38   8.393180e-84      mths_since_issue_d
# 39   3.871994e-38      mths_since_issue_d
# 40   8.464982e-08      mths_since_issue_d
# 41   4.922289e-03      mths_since_issue_d
# 42   9.942819e-32                int_rate
# 43   1.356033e-36                int_rate
# 44   4.578890e-17                int_rate
# 45   8.543059e-05                int_rate
# 46   7.812819e-15          inq_last_6mths
# 47   1.055744e-09          inq_last_6mths
# 48   2.579841e-04          inq_last_6mths
# 49   6.505953e-02          acc_now_delinq
# 50   9.224062e-02              annual_inc
# 51   9.151110e-01              annual_inc
# 52   2.015477e-02              annual_inc
# 53   5.789103e-05              annual_inc
# 54   6.471118e-09              annual_inc
# 55   6.440899e-14              annual_inc
# 56   2.871908e-19              annual_inc
# 57   7.099694e-20              annual_inc
# 58   2.925291e-28              annual_inc
# 59   7.642023e-31              annual_inc
# 60   5.887430e-30              annual_inc
# 61   3.939726e-03                     dti
# 62   3.835659e-07                     dti
# 63   3.912500e-10                     dti
# 64   1.516656e-07                     dti
# 65   4.326273e-05                     dti
# 66   1.816938e-02                     dti
# 67   3.754793e-02                     dti
# 68   1.645268e-01                     dti
# 69   3.756922e-01                     dti
# 70   4.846849e-02  mths_since_last_delinq
# 71   7.020200e-03  mths_since_last_delinq
# 72   4.946431e-04  mths_since_last_delinq
# 73   1.185531e-02  mths_since_last_delinq
# 74   3.167814e-05  mths_since_last_record
# 75   1.678724e-04  mths_since_last_record
# 76   7.240039e-04  mths_since_last_record
# 77   2.603883e-10  mths_since_last_record
# 78   5.872193e-02  mths_since_last_record
# 79   2.315476e-03  mths_since_last_record
# 80            NaN                   grade
# 81            NaN          home_ownership
# 82            NaN              addr_state
# 83            NaN     verification_status
# 84            NaN                 purpose
# 85            NaN     initial_list_status
# 86            NaN                    term
# 87            NaN              emp_length
# 88            NaN      mths_since_issue_d
# 89            NaN                int_rate
# 90            NaN          inq_last_6mths
# 91            NaN          acc_now_delinq
# 92            NaN              annual_inc
# 93            NaN                     dti
# 94            NaN  mths_since_last_delinq
# 95            NaN  mths_since_last_record

# %%
#similar to FICO score
min_score = 300
max_score = 850

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].min()
# Out:
# Original feature name
# Intercept                -1.363017
# acc_now_delinq            0.000000
# addr_state                0.000000
# annual_inc               -0.070674
# dti                       0.000000
# emp_length                0.000000
# grade                     0.000000
# home_ownership            0.000000
# initial_list_status       0.000000
# inq_last_6mths            0.000000
# int_rate                  0.000000
# mths_since_issue_d       -0.082105
# mths_since_last_delinq    0.000000
# mths_since_last_record    0.000000
# purpose                   0.000000
# term                      0.000000
# verification_status      -0.015836
# Name: Coefficients, dtype: float64

# %%
min_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].min().sum()
min_sum_coef
# Out:
# -1.531632495939175

# %%
df_scorecard.groupby('Original feature name')['Coefficients'].max()
# Out:
# Original feature name
# Intercept                -1.363017
# acc_now_delinq            0.195468
# addr_state                0.522930
# annual_inc                0.594423
# dti                       0.375916
# emp_length                0.130579
# grade                     1.150683
# home_ownership            0.113136
# initial_list_status       0.054146
# inq_last_6mths            0.678363
# int_rate                  0.891710
# mths_since_issue_d        1.060861
# mths_since_last_delinq    0.185661
# mths_since_last_record    0.537077
# purpose                   0.304117
# term                      0.073198
# verification_status       0.080402
# Name: Coefficients, dtype: float64

# %%
max_sum_coef = df_scorecard.groupby('Original feature name')['Coefficients'].max().sum()
max_sum_coef
# Out:
# 5.5856525388656655

# %%
df_scorecard['Score - Calculation'] = df_scorecard['Coefficients'] * (max_score - min_score) / (max_sum_coef - min_sum_coef)
df_scorecard
# Out:
#     index                                  Feature name  Coefficients  \
# 0       0                                     Intercept     -1.363017
# 1       1                                       grade:A      1.150683
# 2       2                                       grade:B      0.902683
# 3       3                                       grade:C      0.706017
# 4       4                                       grade:D      0.517070
# 5       5                                       grade:E      0.339875
# 6       6                                       grade:F      0.149022
# 7       7                            home_ownership:OWN      0.103687
# 8       8                       home_ownership:MORTGAGE      0.113136
# 9       9                              addr_state:NM_VA      0.038315
# 10     10                                 addr_state:NY      0.057726
# 11     11                  addr_state:OK_TN_MO_LA_MD_NC      0.060115
# 12     12                                 addr_state:CA      0.063581
# 13     13                        addr_state:UT_KY_AZ_NJ      0.079940
# 14     14                     addr_state:AR_MI_PA_OH_MN      0.137513
# 15     15                     addr_state:RI_MA_DE_SD_IN      0.101512
# 16     16                           addr_state:GA_WA_OR      0.187029
# 17     17                              addr_state:WI_MT      0.249302
# 18     18                                 addr_state:TX      0.223806
# 19     19                              addr_state:IL_CT      0.263615
# 20     20                  addr_state:KS_SC_CO_VT_AK_MS      0.322896
# 21     21                  addr_state:WV_NH_WY_DC_ME_ID      0.522930
# 22     22              verification_status:Not Verified      0.080402
# 23     23           verification_status:Source Verified     -0.015836
# 24     24                           purpose:credit_card      0.304117
# 25     25                    purpose:debt_consolidation      0.200375
# 26     26                    purpose:oth__med__vacation      0.216068
# 27     27           purpose:major_purch__car__home_impr      0.265220
# 28     28                         initial_list_status:w      0.054146
# 29     29                                       term:36      0.073198
# 30     30                                  emp_length:1      0.090339
# 31     31                                emp_length:2-4      0.115451
# 32     32                                emp_length:5-6      0.081700
# 33     33                                emp_length:7-9      0.055107
# 34     34                                 emp_length:10      0.130579
# 35     35                        mths_since_issue_d:<38      1.060861
# 36     36                      mths_since_issue_d:38-39      0.858934
# 37     37                      mths_since_issue_d:40-41      0.759594
# 38     38                      mths_since_issue_d:42-48      0.560892
# 39     39                      mths_since_issue_d:49-52      0.399757
# 40     40                      mths_since_issue_d:53-64      0.156001
# 41     41                      mths_since_issue_d:65-84     -0.082105
# 42     42                               int_rate:<9.548      0.891710
# 43     43                         int_rate:9.548-12.025      0.563528
# 44     44                         int_rate:12.025-15.74      0.308010
# 45     45                         int_rate:15.74-20.281      0.113786
# 46     46                              inq_last_6mths:0      0.678363
# 47     47                            inq_last_6mths:1-2      0.531914
# 48     48                            inq_last_6mths:3-6      0.320662
# 49     49                            acc_now_delinq:>=1      0.195468
# 50     50                            annual_inc:20K-30K     -0.070674
# 51     51                            annual_inc:30K-40K     -0.004288
# 52     52                            annual_inc:40K-50K      0.093152
# 53     53                            annual_inc:50K-60K      0.163083
# 54     54                            annual_inc:60K-70K      0.240573
# 55     55                            annual_inc:70K-80K      0.316972
# 56     56                            annual_inc:80K-90K      0.395119
# 57     57                           annual_inc:90K-100K      0.416305
# 58     58                          annual_inc:100K-120K      0.498071
# 59     59                          annual_inc:120K-140K      0.594423
# 60     60                              annual_inc:>140K      0.534017
# 61     61                                     dti:<=1.4      0.239965
# 62     62                                   dti:1.4-3.5      0.354255
# 63     63                                   dti:3.5-7.7      0.375916
# 64     64                                  dti:7.7-10.5      0.313472
# 65     65                                 dti:10.5-16.1      0.235874
# 66     66                                 dti:16.1-20.3      0.136447
# 67     67                                 dti:20.3-21.7      0.125781
# 68     68                                 dti:21.7-22.4      0.089738
# 69     69                                   dti:22.4-35      0.050562
# 70     70                mths_since_last_delinq:Missing      0.102752
# 71     71                   mths_since_last_delinq:4-30      0.141855
# 72     72                  mths_since_last_delinq:31-56      0.185661
# 73     73                   mths_since_last_delinq:>=57      0.137300
# 74     74                mths_since_last_record:Missing      0.336859
# 75     75                   mths_since_last_record:3-20      0.460786
# 76     76                  mths_since_last_record:21-31      0.379282
# 77     77                  mths_since_last_record:32-80      0.537077
# 78     78                  mths_since_last_record:81-86      0.192636
# 79     79                    mths_since_last_record:>86      0.255172
# 80      0                                       grade:G      0.000000
# 81      1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 82      2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 83      3                  verification_status:Verified      0.000000
# 84      4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 85      5                         initial_list_status:f      0.000000
# 86      6                                       term:60      0.000000
# 87      7                                  emp_length:0      0.000000
# 88      8                        mths_since_issue_d:>84      0.000000
# 89      9                              int_rate:>20.281      0.000000
# 90     10                             inq_last_6mths:>6      0.000000
# 91     11                              acc_now_delinq:0      0.000000
# 92     12                               annual_inc:<20K      0.000000
# 93     13                                       dti:>35      0.000000
# 94     14                    mths_since_last_delinq:0-3      0.000000
# 95     15                    mths_since_last_record:0-2      0.000000
#
#          p_values   Original feature name  Score - Calculation
# 0             NaN               Intercept          -105.329437
# 1    6.493398e-37                   grade            88.920968
# 2    8.562678e-50                   grade            69.756358
# 3    4.328151e-36                   grade            54.558631
# 4    2.846739e-22                   grade            39.957455
# 5    5.407915e-13                   grade            26.264380
# 6    2.340250e-03                   grade            11.515943
# 7    2.427123e-07          home_ownership             8.012608
# 8    2.380389e-19          home_ownership             8.742751
# 9    2.316105e-01              addr_state             2.960827
# 10   1.712761e-02              addr_state             4.460844
# 11   9.382653e-03              addr_state             4.645517
# 12   2.695528e-03              addr_state             4.913342
# 13   1.328778e-03              addr_state             6.177471
# 14   1.001046e-09              addr_state            10.626515
# 15   6.665786e-04              addr_state             7.844472
# 16   2.294597e-12              addr_state            14.452949
# 17   1.629901e-07              addr_state            19.265223
# 18   6.894934e-18              addr_state            17.294970
# 19   1.750119e-19              addr_state            20.371259
# 20   1.120202e-25              addr_state            24.952348
# 21   8.378406e-23              addr_state            40.410319
# 22   3.500395e-08     verification_status             6.213168
# 23   2.376157e-01     verification_status            -1.223729
# 24   5.128792e-27                 purpose            23.501157
# 25   1.231238e-14                 purpose            15.484318
# 26   3.656105e-12                 purpose            16.697025
# 27   1.940163e-17                 purpose            20.495350
# 28   3.365657e-05     initial_list_status             4.184195
# 29   1.504587e-07                    term             5.656463
# 30   4.841712e-04              emp_length             6.981111
# 31   8.191726e-10              emp_length             8.921699
# 32   1.298719e-04              emp_length             6.313490
# 33   7.940178e-03              emp_length             4.258474
# 34   1.196903e-12              emp_length            10.090740
# 35  2.492088e-175      mths_since_issue_d            81.979803
# 36  1.263264e-144      mths_since_issue_d            66.375528
# 37  2.259928e-119      mths_since_issue_d            58.698856
# 38   8.393180e-84      mths_since_issue_d            43.343831
# 39   3.871994e-38      mths_since_issue_d            30.891856
# 40   8.464982e-08      mths_since_issue_d            12.055266
# 41   4.922289e-03      mths_since_issue_d            -6.344803
# 42   9.942819e-32                int_rate            68.908406
# 43   1.356033e-36                int_rate            43.547569
# 44   4.578890e-17                int_rate            23.801999
# 45   8.543059e-05                int_rate             8.792984
# 46   7.812819e-15          inq_last_6mths            52.421606
# 47   1.055744e-09          inq_last_6mths            41.104565
# 48   2.579841e-04          inq_last_6mths            24.779660
# 49   6.505953e-02          acc_now_delinq            15.105152
# 50   9.224062e-02              annual_inc            -5.461471
# 51   9.151110e-01              annual_inc            -0.331394
# 52   2.015477e-02              annual_inc             7.198450
# 53   5.789103e-05              annual_inc            12.602482
# 54   6.471118e-09              annual_inc            18.590703
# 55   6.440899e-14              annual_inc            24.494537
# 56   2.871908e-19              annual_inc            30.533463
# 57   7.099694e-20              annual_inc            32.170635
# 58   2.925291e-28              annual_inc            38.489267
# 59   7.642023e-31              annual_inc            45.935006
# 60   5.887430e-30              annual_inc            41.267036
# 61   3.939726e-03                     dti            18.543699
# 62   3.835659e-07                     dti            27.375631
# 63   3.912500e-10                     dti            29.049500
# 64   1.516656e-07                     dti            24.224048
# 65   4.326273e-05                     dti            18.227527
# 66   1.816938e-02                     dti            10.544168
# 67   3.754793e-02                     dti             9.719899
# 68   1.645268e-01                     dti             6.934652
# 69   3.756922e-01                     dti             3.907291
# 70   4.846849e-02  mths_since_last_delinq             7.940343
# 71   7.020200e-03  mths_since_last_delinq            10.962089
# 72   4.946431e-04  mths_since_last_delinq            14.347270
# 73   1.185531e-02  mths_since_last_delinq            10.610075
# 74   3.167814e-05  mths_since_last_record            26.031357
# 75   1.678724e-04  mths_since_last_record            35.607992
# 76   7.240039e-04  mths_since_last_record            29.309676
# 77   2.603883e-10  mths_since_last_record            41.503494
# 78   5.872193e-02  mths_since_last_record            14.886253
# 79   2.315476e-03  mths_since_last_record            19.718848
# 80            NaN                   grade             0.000000
# 81            NaN          home_ownership             0.000000
# 82            NaN              addr_state             0.000000
# 83            NaN     verification_status             0.000000
# 84            NaN                 purpose             0.000000
# 85            NaN     initial_list_status             0.000000
# 86            NaN                    term             0.000000
# 87            NaN              emp_length             0.000000
# 88            NaN      mths_since_issue_d             0.000000
# 89            NaN                int_rate             0.000000
# 90            NaN          inq_last_6mths             0.000000
# 91            NaN          acc_now_delinq             0.000000
# 92            NaN              annual_inc             0.000000
# 93            NaN                     dti             0.000000
# 94            NaN  mths_since_last_delinq             0.000000
# 95            NaN  mths_since_last_record             0.000000

# %%
df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
df_scorecard
# Out:
# <ipython-input-96-f69c049793b7>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Calculation'][0] = ((df_scorecard['Coefficients'][0] - min_sum_coef) / (max_sum_coef - min_sum_coef)) * (max_score - min_score) + min_score
#     index                                  Feature name  Coefficients  \
# 0       0                                     Intercept     -1.363017
# 1       1                                       grade:A      1.150683
# 2       2                                       grade:B      0.902683
# 3       3                                       grade:C      0.706017
# 4       4                                       grade:D      0.517070
# 5       5                                       grade:E      0.339875
# 6       6                                       grade:F      0.149022
# 7       7                            home_ownership:OWN      0.103687
# 8       8                       home_ownership:MORTGAGE      0.113136
# 9       9                              addr_state:NM_VA      0.038315
# 10     10                                 addr_state:NY      0.057726
# 11     11                  addr_state:OK_TN_MO_LA_MD_NC      0.060115
# 12     12                                 addr_state:CA      0.063581
# 13     13                        addr_state:UT_KY_AZ_NJ      0.079940
# 14     14                     addr_state:AR_MI_PA_OH_MN      0.137513
# 15     15                     addr_state:RI_MA_DE_SD_IN      0.101512
# 16     16                           addr_state:GA_WA_OR      0.187029
# 17     17                              addr_state:WI_MT      0.249302
# 18     18                                 addr_state:TX      0.223806
# 19     19                              addr_state:IL_CT      0.263615
# 20     20                  addr_state:KS_SC_CO_VT_AK_MS      0.322896
# 21     21                  addr_state:WV_NH_WY_DC_ME_ID      0.522930
# 22     22              verification_status:Not Verified      0.080402
# 23     23           verification_status:Source Verified     -0.015836
# 24     24                           purpose:credit_card      0.304117
# 25     25                    purpose:debt_consolidation      0.200375
# 26     26                    purpose:oth__med__vacation      0.216068
# 27     27           purpose:major_purch__car__home_impr      0.265220
# 28     28                         initial_list_status:w      0.054146
# 29     29                                       term:36      0.073198
# 30     30                                  emp_length:1      0.090339
# 31     31                                emp_length:2-4      0.115451
# 32     32                                emp_length:5-6      0.081700
# 33     33                                emp_length:7-9      0.055107
# 34     34                                 emp_length:10      0.130579
# 35     35                        mths_since_issue_d:<38      1.060861
# 36     36                      mths_since_issue_d:38-39      0.858934
# 37     37                      mths_since_issue_d:40-41      0.759594
# 38     38                      mths_since_issue_d:42-48      0.560892
# 39     39                      mths_since_issue_d:49-52      0.399757
# 40     40                      mths_since_issue_d:53-64      0.156001
# 41     41                      mths_since_issue_d:65-84     -0.082105
# 42     42                               int_rate:<9.548      0.891710
# 43     43                         int_rate:9.548-12.025      0.563528
# 44     44                         int_rate:12.025-15.74      0.308010
# 45     45                         int_rate:15.74-20.281      0.113786
# 46     46                              inq_last_6mths:0      0.678363
# 47     47                            inq_last_6mths:1-2      0.531914
# 48     48                            inq_last_6mths:3-6      0.320662
# 49     49                            acc_now_delinq:>=1      0.195468
# 50     50                            annual_inc:20K-30K     -0.070674
# 51     51                            annual_inc:30K-40K     -0.004288
# 52     52                            annual_inc:40K-50K      0.093152
# 53     53                            annual_inc:50K-60K      0.163083
# 54     54                            annual_inc:60K-70K      0.240573
# 55     55                            annual_inc:70K-80K      0.316972
# 56     56                            annual_inc:80K-90K      0.395119
# 57     57                           annual_inc:90K-100K      0.416305
# 58     58                          annual_inc:100K-120K      0.498071
# 59     59                          annual_inc:120K-140K      0.594423
# 60     60                              annual_inc:>140K      0.534017
# 61     61                                     dti:<=1.4      0.239965
# 62     62                                   dti:1.4-3.5      0.354255
# 63     63                                   dti:3.5-7.7      0.375916
# 64     64                                  dti:7.7-10.5      0.313472
# 65     65                                 dti:10.5-16.1      0.235874
# 66     66                                 dti:16.1-20.3      0.136447
# 67     67                                 dti:20.3-21.7      0.125781
# 68     68                                 dti:21.7-22.4      0.089738
# 69     69                                   dti:22.4-35      0.050562
# 70     70                mths_since_last_delinq:Missing      0.102752
# 71     71                   mths_since_last_delinq:4-30      0.141855
# 72     72                  mths_since_last_delinq:31-56      0.185661
# 73     73                   mths_since_last_delinq:>=57      0.137300
# 74     74                mths_since_last_record:Missing      0.336859
# 75     75                   mths_since_last_record:3-20      0.460786
# 76     76                  mths_since_last_record:21-31      0.379282
# 77     77                  mths_since_last_record:32-80      0.537077
# 78     78                  mths_since_last_record:81-86      0.192636
# 79     79                    mths_since_last_record:>86      0.255172
# 80      0                                       grade:G      0.000000
# 81      1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 82      2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 83      3                  verification_status:Verified      0.000000
# 84      4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 85      5                         initial_list_status:f      0.000000
# 86      6                                       term:60      0.000000
# 87      7                                  emp_length:0      0.000000
# 88      8                        mths_since_issue_d:>84      0.000000
# 89      9                              int_rate:>20.281      0.000000
# 90     10                             inq_last_6mths:>6      0.000000
# 91     11                              acc_now_delinq:0      0.000000
# 92     12                               annual_inc:<20K      0.000000
# 93     13                                       dti:>35      0.000000
# 94     14                    mths_since_last_delinq:0-3      0.000000
# 95     15                    mths_since_last_record:0-2      0.000000
#
#          p_values   Original feature name  Score - Calculation
# 0             NaN               Intercept           313.030004
# 1    6.493398e-37                   grade            88.920968
# 2    8.562678e-50                   grade            69.756358
# 3    4.328151e-36                   grade            54.558631
# 4    2.846739e-22                   grade            39.957455
# 5    5.407915e-13                   grade            26.264380
# 6    2.340250e-03                   grade            11.515943
# 7    2.427123e-07          home_ownership             8.012608
# 8    2.380389e-19          home_ownership             8.742751
# 9    2.316105e-01              addr_state             2.960827
# 10   1.712761e-02              addr_state             4.460844
# 11   9.382653e-03              addr_state             4.645517
# 12   2.695528e-03              addr_state             4.913342
# 13   1.328778e-03              addr_state             6.177471
# 14   1.001046e-09              addr_state            10.626515
# 15   6.665786e-04              addr_state             7.844472
# 16   2.294597e-12              addr_state            14.452949
# 17   1.629901e-07              addr_state            19.265223
# 18   6.894934e-18              addr_state            17.294970
# 19   1.750119e-19              addr_state            20.371259
# 20   1.120202e-25              addr_state            24.952348
# 21   8.378406e-23              addr_state            40.410319
# 22   3.500395e-08     verification_status             6.213168
# 23   2.376157e-01     verification_status            -1.223729
# 24   5.128792e-27                 purpose            23.501157
# 25   1.231238e-14                 purpose            15.484318
# 26   3.656105e-12                 purpose            16.697025
# 27   1.940163e-17                 purpose            20.495350
# 28   3.365657e-05     initial_list_status             4.184195
# 29   1.504587e-07                    term             5.656463
# 30   4.841712e-04              emp_length             6.981111
# 31   8.191726e-10              emp_length             8.921699
# 32   1.298719e-04              emp_length             6.313490
# 33   7.940178e-03              emp_length             4.258474
# 34   1.196903e-12              emp_length            10.090740
# 35  2.492088e-175      mths_since_issue_d            81.979803
# 36  1.263264e-144      mths_since_issue_d            66.375528
# 37  2.259928e-119      mths_since_issue_d            58.698856
# 38   8.393180e-84      mths_since_issue_d            43.343831
# 39   3.871994e-38      mths_since_issue_d            30.891856
# 40   8.464982e-08      mths_since_issue_d            12.055266
# 41   4.922289e-03      mths_since_issue_d            -6.344803
# 42   9.942819e-32                int_rate            68.908406
# 43   1.356033e-36                int_rate            43.547569
# 44   4.578890e-17                int_rate            23.801999
# 45   8.543059e-05                int_rate             8.792984
# 46   7.812819e-15          inq_last_6mths            52.421606
# 47   1.055744e-09          inq_last_6mths            41.104565
# 48   2.579841e-04          inq_last_6mths            24.779660
# 49   6.505953e-02          acc_now_delinq            15.105152
# 50   9.224062e-02              annual_inc            -5.461471
# 51   9.151110e-01              annual_inc            -0.331394
# 52   2.015477e-02              annual_inc             7.198450
# 53   5.789103e-05              annual_inc            12.602482
# 54   6.471118e-09              annual_inc            18.590703
# 55   6.440899e-14              annual_inc            24.494537
# 56   2.871908e-19              annual_inc            30.533463
# 57   7.099694e-20              annual_inc            32.170635
# 58   2.925291e-28              annual_inc            38.489267
# 59   7.642023e-31              annual_inc            45.935006
# 60   5.887430e-30              annual_inc            41.267036
# 61   3.939726e-03                     dti            18.543699
# 62   3.835659e-07                     dti            27.375631
# 63   3.912500e-10                     dti            29.049500
# 64   1.516656e-07                     dti            24.224048
# 65   4.326273e-05                     dti            18.227527
# 66   1.816938e-02                     dti            10.544168
# 67   3.754793e-02                     dti             9.719899
# 68   1.645268e-01                     dti             6.934652
# 69   3.756922e-01                     dti             3.907291
# 70   4.846849e-02  mths_since_last_delinq             7.940343
# 71   7.020200e-03  mths_since_last_delinq            10.962089
# 72   4.946431e-04  mths_since_last_delinq            14.347270
# 73   1.185531e-02  mths_since_last_delinq            10.610075
# 74   3.167814e-05  mths_since_last_record            26.031357
# 75   1.678724e-04  mths_since_last_record            35.607992
# 76   7.240039e-04  mths_since_last_record            29.309676
# 77   2.603883e-10  mths_since_last_record            41.503494
# 78   5.872193e-02  mths_since_last_record            14.886253
# 79   2.315476e-03  mths_since_last_record            19.718848
# 80            NaN                   grade             0.000000
# 81            NaN          home_ownership             0.000000
# 82            NaN              addr_state             0.000000
# 83            NaN     verification_status             0.000000
# 84            NaN                 purpose             0.000000
# 85            NaN     initial_list_status             0.000000
# 86            NaN                    term             0.000000
# 87            NaN              emp_length             0.000000
# 88            NaN      mths_since_issue_d             0.000000
# 89            NaN                int_rate             0.000000
# 90            NaN          inq_last_6mths             0.000000
# 91            NaN          acc_now_delinq             0.000000
# 92            NaN              annual_inc             0.000000
# 93            NaN                     dti             0.000000
# 94            NaN  mths_since_last_delinq             0.000000
# 95            NaN  mths_since_last_record             0.000000

# %%
df_scorecard['Score - Preliminary'] = df_scorecard['Score - Calculation'].round()
df_scorecard
# Out:
#     index                                  Feature name  Coefficients  \
# 0       0                                     Intercept     -1.363017
# 1       1                                       grade:A      1.150683
# 2       2                                       grade:B      0.902683
# 3       3                                       grade:C      0.706017
# 4       4                                       grade:D      0.517070
# 5       5                                       grade:E      0.339875
# 6       6                                       grade:F      0.149022
# 7       7                            home_ownership:OWN      0.103687
# 8       8                       home_ownership:MORTGAGE      0.113136
# 9       9                              addr_state:NM_VA      0.038315
# 10     10                                 addr_state:NY      0.057726
# 11     11                  addr_state:OK_TN_MO_LA_MD_NC      0.060115
# 12     12                                 addr_state:CA      0.063581
# 13     13                        addr_state:UT_KY_AZ_NJ      0.079940
# 14     14                     addr_state:AR_MI_PA_OH_MN      0.137513
# 15     15                     addr_state:RI_MA_DE_SD_IN      0.101512
# 16     16                           addr_state:GA_WA_OR      0.187029
# 17     17                              addr_state:WI_MT      0.249302
# 18     18                                 addr_state:TX      0.223806
# 19     19                              addr_state:IL_CT      0.263615
# 20     20                  addr_state:KS_SC_CO_VT_AK_MS      0.322896
# 21     21                  addr_state:WV_NH_WY_DC_ME_ID      0.522930
# 22     22              verification_status:Not Verified      0.080402
# 23     23           verification_status:Source Verified     -0.015836
# 24     24                           purpose:credit_card      0.304117
# 25     25                    purpose:debt_consolidation      0.200375
# 26     26                    purpose:oth__med__vacation      0.216068
# 27     27           purpose:major_purch__car__home_impr      0.265220
# 28     28                         initial_list_status:w      0.054146
# 29     29                                       term:36      0.073198
# 30     30                                  emp_length:1      0.090339
# 31     31                                emp_length:2-4      0.115451
# 32     32                                emp_length:5-6      0.081700
# 33     33                                emp_length:7-9      0.055107
# 34     34                                 emp_length:10      0.130579
# 35     35                        mths_since_issue_d:<38      1.060861
# 36     36                      mths_since_issue_d:38-39      0.858934
# 37     37                      mths_since_issue_d:40-41      0.759594
# 38     38                      mths_since_issue_d:42-48      0.560892
# 39     39                      mths_since_issue_d:49-52      0.399757
# 40     40                      mths_since_issue_d:53-64      0.156001
# 41     41                      mths_since_issue_d:65-84     -0.082105
# 42     42                               int_rate:<9.548      0.891710
# 43     43                         int_rate:9.548-12.025      0.563528
# 44     44                         int_rate:12.025-15.74      0.308010
# 45     45                         int_rate:15.74-20.281      0.113786
# 46     46                              inq_last_6mths:0      0.678363
# 47     47                            inq_last_6mths:1-2      0.531914
# 48     48                            inq_last_6mths:3-6      0.320662
# 49     49                            acc_now_delinq:>=1      0.195468
# 50     50                            annual_inc:20K-30K     -0.070674
# 51     51                            annual_inc:30K-40K     -0.004288
# 52     52                            annual_inc:40K-50K      0.093152
# 53     53                            annual_inc:50K-60K      0.163083
# 54     54                            annual_inc:60K-70K      0.240573
# 55     55                            annual_inc:70K-80K      0.316972
# 56     56                            annual_inc:80K-90K      0.395119
# 57     57                           annual_inc:90K-100K      0.416305
# 58     58                          annual_inc:100K-120K      0.498071
# 59     59                          annual_inc:120K-140K      0.594423
# 60     60                              annual_inc:>140K      0.534017
# 61     61                                     dti:<=1.4      0.239965
# 62     62                                   dti:1.4-3.5      0.354255
# 63     63                                   dti:3.5-7.7      0.375916
# 64     64                                  dti:7.7-10.5      0.313472
# 65     65                                 dti:10.5-16.1      0.235874
# 66     66                                 dti:16.1-20.3      0.136447
# 67     67                                 dti:20.3-21.7      0.125781
# 68     68                                 dti:21.7-22.4      0.089738
# 69     69                                   dti:22.4-35      0.050562
# 70     70                mths_since_last_delinq:Missing      0.102752
# 71     71                   mths_since_last_delinq:4-30      0.141855
# 72     72                  mths_since_last_delinq:31-56      0.185661
# 73     73                   mths_since_last_delinq:>=57      0.137300
# 74     74                mths_since_last_record:Missing      0.336859
# 75     75                   mths_since_last_record:3-20      0.460786
# 76     76                  mths_since_last_record:21-31      0.379282
# 77     77                  mths_since_last_record:32-80      0.537077
# 78     78                  mths_since_last_record:81-86      0.192636
# 79     79                    mths_since_last_record:>86      0.255172
# 80      0                                       grade:G      0.000000
# 81      1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 82      2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 83      3                  verification_status:Verified      0.000000
# 84      4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 85      5                         initial_list_status:f      0.000000
# 86      6                                       term:60      0.000000
# 87      7                                  emp_length:0      0.000000
# 88      8                        mths_since_issue_d:>84      0.000000
# 89      9                              int_rate:>20.281      0.000000
# 90     10                             inq_last_6mths:>6      0.000000
# 91     11                              acc_now_delinq:0      0.000000
# 92     12                               annual_inc:<20K      0.000000
# 93     13                                       dti:>35      0.000000
# 94     14                    mths_since_last_delinq:0-3      0.000000
# 95     15                    mths_since_last_record:0-2      0.000000
#
#          p_values   Original feature name  Score - Calculation  \
# 0             NaN               Intercept           313.030004
# 1    6.493398e-37                   grade            88.920968
# 2    8.562678e-50                   grade            69.756358
# 3    4.328151e-36                   grade            54.558631
# 4    2.846739e-22                   grade            39.957455
# 5    5.407915e-13                   grade            26.264380
# 6    2.340250e-03                   grade            11.515943
# 7    2.427123e-07          home_ownership             8.012608
# 8    2.380389e-19          home_ownership             8.742751
# 9    2.316105e-01              addr_state             2.960827
# 10   1.712761e-02              addr_state             4.460844
# 11   9.382653e-03              addr_state             4.645517
# 12   2.695528e-03              addr_state             4.913342
# 13   1.328778e-03              addr_state             6.177471
# 14   1.001046e-09              addr_state            10.626515
# 15   6.665786e-04              addr_state             7.844472
# 16   2.294597e-12              addr_state            14.452949
# 17   1.629901e-07              addr_state            19.265223
# 18   6.894934e-18              addr_state            17.294970
# 19   1.750119e-19              addr_state            20.371259
# 20   1.120202e-25              addr_state            24.952348
# 21   8.378406e-23              addr_state            40.410319
# 22   3.500395e-08     verification_status             6.213168
# 23   2.376157e-01     verification_status            -1.223729
# 24   5.128792e-27                 purpose            23.501157
# 25   1.231238e-14                 purpose            15.484318
# 26   3.656105e-12                 purpose            16.697025
# 27   1.940163e-17                 purpose            20.495350
# 28   3.365657e-05     initial_list_status             4.184195
# 29   1.504587e-07                    term             5.656463
# 30   4.841712e-04              emp_length             6.981111
# 31   8.191726e-10              emp_length             8.921699
# 32   1.298719e-04              emp_length             6.313490
# 33   7.940178e-03              emp_length             4.258474
# 34   1.196903e-12              emp_length            10.090740
# 35  2.492088e-175      mths_since_issue_d            81.979803
# 36  1.263264e-144      mths_since_issue_d            66.375528
# 37  2.259928e-119      mths_since_issue_d            58.698856
# 38   8.393180e-84      mths_since_issue_d            43.343831
# 39   3.871994e-38      mths_since_issue_d            30.891856
# 40   8.464982e-08      mths_since_issue_d            12.055266
# 41   4.922289e-03      mths_since_issue_d            -6.344803
# 42   9.942819e-32                int_rate            68.908406
# 43   1.356033e-36                int_rate            43.547569
# 44   4.578890e-17                int_rate            23.801999
# 45   8.543059e-05                int_rate             8.792984
# 46   7.812819e-15          inq_last_6mths            52.421606
# 47   1.055744e-09          inq_last_6mths            41.104565
# 48   2.579841e-04          inq_last_6mths            24.779660
# 49   6.505953e-02          acc_now_delinq            15.105152
# 50   9.224062e-02              annual_inc            -5.461471
# 51   9.151110e-01              annual_inc            -0.331394
# 52   2.015477e-02              annual_inc             7.198450
# 53   5.789103e-05              annual_inc            12.602482
# 54   6.471118e-09              annual_inc            18.590703
# 55   6.440899e-14              annual_inc            24.494537
# 56   2.871908e-19              annual_inc            30.533463
# 57   7.099694e-20              annual_inc            32.170635
# 58   2.925291e-28              annual_inc            38.489267
# 59   7.642023e-31              annual_inc            45.935006
# 60   5.887430e-30              annual_inc            41.267036
# 61   3.939726e-03                     dti            18.543699
# 62   3.835659e-07                     dti            27.375631
# 63   3.912500e-10                     dti            29.049500
# 64   1.516656e-07                     dti            24.224048
# 65   4.326273e-05                     dti            18.227527
# 66   1.816938e-02                     dti            10.544168
# 67   3.754793e-02                     dti             9.719899
# 68   1.645268e-01                     dti             6.934652
# 69   3.756922e-01                     dti             3.907291
# 70   4.846849e-02  mths_since_last_delinq             7.940343
# 71   7.020200e-03  mths_since_last_delinq            10.962089
# 72   4.946431e-04  mths_since_last_delinq            14.347270
# 73   1.185531e-02  mths_since_last_delinq            10.610075
# 74   3.167814e-05  mths_since_last_record            26.031357
# 75   1.678724e-04  mths_since_last_record            35.607992
# 76   7.240039e-04  mths_since_last_record            29.309676
# 77   2.603883e-10  mths_since_last_record            41.503494
# 78   5.872193e-02  mths_since_last_record            14.886253
# 79   2.315476e-03  mths_since_last_record            19.718848
# 80            NaN                   grade             0.000000
# 81            NaN          home_ownership             0.000000
# 82            NaN              addr_state             0.000000
# 83            NaN     verification_status             0.000000
# 84            NaN                 purpose             0.000000
# 85            NaN     initial_list_status             0.000000
# 86            NaN                    term             0.000000
# 87            NaN              emp_length             0.000000
# 88            NaN      mths_since_issue_d             0.000000
# 89            NaN                int_rate             0.000000
# 90            NaN          inq_last_6mths             0.000000
# 91            NaN          acc_now_delinq             0.000000
# 92            NaN              annual_inc             0.000000
# 93            NaN                     dti             0.000000
# 94            NaN  mths_since_last_delinq             0.000000
# 95            NaN  mths_since_last_record             0.000000
#
#     Score - Preliminary
# 0                 313.0
# 1                  89.0
# 2                  70.0
# 3                  55.0
# 4                  40.0
# 5                  26.0
# 6                  12.0
# 7                   8.0
# 8                   9.0
# 9                   3.0
# 10                  4.0
# 11                  5.0
# 12                  5.0
# 13                  6.0
# 14                 11.0
# 15                  8.0
# 16                 14.0
# 17                 19.0
# 18                 17.0
# 19                 20.0
# 20                 25.0
# 21                 40.0
# 22                  6.0
# 23                 -1.0
# 24                 24.0
# 25                 15.0
# 26                 17.0
# 27                 20.0
# 28                  4.0
# 29                  6.0
# 30                  7.0
# 31                  9.0
# 32                  6.0
# 33                  4.0
# 34                 10.0
# 35                 82.0
# 36                 66.0
# 37                 59.0
# 38                 43.0
# 39                 31.0
# 40                 12.0
# 41                 -6.0
# 42                 69.0
# 43                 44.0
# 44                 24.0
# 45                  9.0
# 46                 52.0
# 47                 41.0
# 48                 25.0
# 49                 15.0
# 50                 -5.0
# 51                 -0.0
# 52                  7.0
# 53                 13.0
# 54                 19.0
# 55                 24.0
# 56                 31.0
# 57                 32.0
# 58                 38.0
# 59                 46.0
# 60                 41.0
# 61                 19.0
# 62                 27.0
# 63                 29.0
# 64                 24.0
# 65                 18.0
# 66                 11.0
# 67                 10.0
# 68                  7.0
# 69                  4.0
# 70                  8.0
# 71                 11.0
# 72                 14.0
# 73                 11.0
# 74                 26.0
# 75                 36.0
# 76                 29.0
# 77                 42.0
# 78                 15.0
# 79                 20.0
# 80                  0.0
# 81                  0.0
# 82                  0.0
# 83                  0.0
# 84                  0.0
# 85                  0.0
# 86                  0.0
# 87                  0.0
# 88                  0.0
# 89                  0.0
# 90                  0.0
# 91                  0.0
# 92                  0.0
# 93                  0.0
# 94                  0.0
# 95                  0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].min().sum()
min_sum_score_prel
# Out:
# 301.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Preliminary'].max().sum()
max_sum_score_prel
# Out:
# 850.0

# %%
# One has to be subtracted from the minimum score for one original variable

# %%
df_scorecard['Difference'] = df_scorecard['Score - Preliminary'] - df_scorecard['Score - Calculation']
df_scorecard
# Out:
#     index                                  Feature name  Coefficients  \
# 0       0                                     Intercept     -1.363017
# 1       1                                       grade:A      1.150683
# 2       2                                       grade:B      0.902683
# 3       3                                       grade:C      0.706017
# 4       4                                       grade:D      0.517070
# 5       5                                       grade:E      0.339875
# 6       6                                       grade:F      0.149022
# 7       7                            home_ownership:OWN      0.103687
# 8       8                       home_ownership:MORTGAGE      0.113136
# 9       9                              addr_state:NM_VA      0.038315
# 10     10                                 addr_state:NY      0.057726
# 11     11                  addr_state:OK_TN_MO_LA_MD_NC      0.060115
# 12     12                                 addr_state:CA      0.063581
# 13     13                        addr_state:UT_KY_AZ_NJ      0.079940
# 14     14                     addr_state:AR_MI_PA_OH_MN      0.137513
# 15     15                     addr_state:RI_MA_DE_SD_IN      0.101512
# 16     16                           addr_state:GA_WA_OR      0.187029
# 17     17                              addr_state:WI_MT      0.249302
# 18     18                                 addr_state:TX      0.223806
# 19     19                              addr_state:IL_CT      0.263615
# 20     20                  addr_state:KS_SC_CO_VT_AK_MS      0.322896
# 21     21                  addr_state:WV_NH_WY_DC_ME_ID      0.522930
# 22     22              verification_status:Not Verified      0.080402
# 23     23           verification_status:Source Verified     -0.015836
# 24     24                           purpose:credit_card      0.304117
# 25     25                    purpose:debt_consolidation      0.200375
# 26     26                    purpose:oth__med__vacation      0.216068
# 27     27           purpose:major_purch__car__home_impr      0.265220
# 28     28                         initial_list_status:w      0.054146
# 29     29                                       term:36      0.073198
# 30     30                                  emp_length:1      0.090339
# 31     31                                emp_length:2-4      0.115451
# 32     32                                emp_length:5-6      0.081700
# 33     33                                emp_length:7-9      0.055107
# 34     34                                 emp_length:10      0.130579
# 35     35                        mths_since_issue_d:<38      1.060861
# 36     36                      mths_since_issue_d:38-39      0.858934
# 37     37                      mths_since_issue_d:40-41      0.759594
# 38     38                      mths_since_issue_d:42-48      0.560892
# 39     39                      mths_since_issue_d:49-52      0.399757
# 40     40                      mths_since_issue_d:53-64      0.156001
# 41     41                      mths_since_issue_d:65-84     -0.082105
# 42     42                               int_rate:<9.548      0.891710
# 43     43                         int_rate:9.548-12.025      0.563528
# 44     44                         int_rate:12.025-15.74      0.308010
# 45     45                         int_rate:15.74-20.281      0.113786
# 46     46                              inq_last_6mths:0      0.678363
# 47     47                            inq_last_6mths:1-2      0.531914
# 48     48                            inq_last_6mths:3-6      0.320662
# 49     49                            acc_now_delinq:>=1      0.195468
# 50     50                            annual_inc:20K-30K     -0.070674
# 51     51                            annual_inc:30K-40K     -0.004288
# 52     52                            annual_inc:40K-50K      0.093152
# 53     53                            annual_inc:50K-60K      0.163083
# 54     54                            annual_inc:60K-70K      0.240573
# 55     55                            annual_inc:70K-80K      0.316972
# 56     56                            annual_inc:80K-90K      0.395119
# 57     57                           annual_inc:90K-100K      0.416305
# 58     58                          annual_inc:100K-120K      0.498071
# 59     59                          annual_inc:120K-140K      0.594423
# 60     60                              annual_inc:>140K      0.534017
# 61     61                                     dti:<=1.4      0.239965
# 62     62                                   dti:1.4-3.5      0.354255
# 63     63                                   dti:3.5-7.7      0.375916
# 64     64                                  dti:7.7-10.5      0.313472
# 65     65                                 dti:10.5-16.1      0.235874
# 66     66                                 dti:16.1-20.3      0.136447
# 67     67                                 dti:20.3-21.7      0.125781
# 68     68                                 dti:21.7-22.4      0.089738
# 69     69                                   dti:22.4-35      0.050562
# 70     70                mths_since_last_delinq:Missing      0.102752
# 71     71                   mths_since_last_delinq:4-30      0.141855
# 72     72                  mths_since_last_delinq:31-56      0.185661
# 73     73                   mths_since_last_delinq:>=57      0.137300
# 74     74                mths_since_last_record:Missing      0.336859
# 75     75                   mths_since_last_record:3-20      0.460786
# 76     76                  mths_since_last_record:21-31      0.379282
# 77     77                  mths_since_last_record:32-80      0.537077
# 78     78                  mths_since_last_record:81-86      0.192636
# 79     79                    mths_since_last_record:>86      0.255172
# 80      0                                       grade:G      0.000000
# 81      1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 82      2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 83      3                  verification_status:Verified      0.000000
# 84      4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 85      5                         initial_list_status:f      0.000000
# 86      6                                       term:60      0.000000
# 87      7                                  emp_length:0      0.000000
# 88      8                        mths_since_issue_d:>84      0.000000
# 89      9                              int_rate:>20.281      0.000000
# 90     10                             inq_last_6mths:>6      0.000000
# 91     11                              acc_now_delinq:0      0.000000
# 92     12                               annual_inc:<20K      0.000000
# 93     13                                       dti:>35      0.000000
# 94     14                    mths_since_last_delinq:0-3      0.000000
# 95     15                    mths_since_last_record:0-2      0.000000
#
#          p_values   Original feature name  Score - Calculation  \
# 0             NaN               Intercept           313.030004
# 1    6.493398e-37                   grade            88.920968
# 2    8.562678e-50                   grade            69.756358
# 3    4.328151e-36                   grade            54.558631
# 4    2.846739e-22                   grade            39.957455
# 5    5.407915e-13                   grade            26.264380
# 6    2.340250e-03                   grade            11.515943
# 7    2.427123e-07          home_ownership             8.012608
# 8    2.380389e-19          home_ownership             8.742751
# 9    2.316105e-01              addr_state             2.960827
# 10   1.712761e-02              addr_state             4.460844
# 11   9.382653e-03              addr_state             4.645517
# 12   2.695528e-03              addr_state             4.913342
# 13   1.328778e-03              addr_state             6.177471
# 14   1.001046e-09              addr_state            10.626515
# 15   6.665786e-04              addr_state             7.844472
# 16   2.294597e-12              addr_state            14.452949
# 17   1.629901e-07              addr_state            19.265223
# 18   6.894934e-18              addr_state            17.294970
# 19   1.750119e-19              addr_state            20.371259
# 20   1.120202e-25              addr_state            24.952348
# 21   8.378406e-23              addr_state            40.410319
# 22   3.500395e-08     verification_status             6.213168
# 23   2.376157e-01     verification_status            -1.223729
# 24   5.128792e-27                 purpose            23.501157
# 25   1.231238e-14                 purpose            15.484318
# 26   3.656105e-12                 purpose            16.697025
# 27   1.940163e-17                 purpose            20.495350
# 28   3.365657e-05     initial_list_status             4.184195
# 29   1.504587e-07                    term             5.656463
# 30   4.841712e-04              emp_length             6.981111
# 31   8.191726e-10              emp_length             8.921699
# 32   1.298719e-04              emp_length             6.313490
# 33   7.940178e-03              emp_length             4.258474
# 34   1.196903e-12              emp_length            10.090740
# 35  2.492088e-175      mths_since_issue_d            81.979803
# 36  1.263264e-144      mths_since_issue_d            66.375528
# 37  2.259928e-119      mths_since_issue_d            58.698856
# 38   8.393180e-84      mths_since_issue_d            43.343831
# 39   3.871994e-38      mths_since_issue_d            30.891856
# 40   8.464982e-08      mths_since_issue_d            12.055266
# 41   4.922289e-03      mths_since_issue_d            -6.344803
# 42   9.942819e-32                int_rate            68.908406
# 43   1.356033e-36                int_rate            43.547569
# 44   4.578890e-17                int_rate            23.801999
# 45   8.543059e-05                int_rate             8.792984
# 46   7.812819e-15          inq_last_6mths            52.421606
# 47   1.055744e-09          inq_last_6mths            41.104565
# 48   2.579841e-04          inq_last_6mths            24.779660
# 49   6.505953e-02          acc_now_delinq            15.105152
# 50   9.224062e-02              annual_inc            -5.461471
# 51   9.151110e-01              annual_inc            -0.331394
# 52   2.015477e-02              annual_inc             7.198450
# 53   5.789103e-05              annual_inc            12.602482
# 54   6.471118e-09              annual_inc            18.590703
# 55   6.440899e-14              annual_inc            24.494537
# 56   2.871908e-19              annual_inc            30.533463
# 57   7.099694e-20              annual_inc            32.170635
# 58   2.925291e-28              annual_inc            38.489267
# 59   7.642023e-31              annual_inc            45.935006
# 60   5.887430e-30              annual_inc            41.267036
# 61   3.939726e-03                     dti            18.543699
# 62   3.835659e-07                     dti            27.375631
# 63   3.912500e-10                     dti            29.049500
# 64   1.516656e-07                     dti            24.224048
# 65   4.326273e-05                     dti            18.227527
# 66   1.816938e-02                     dti            10.544168
# 67   3.754793e-02                     dti             9.719899
# 68   1.645268e-01                     dti             6.934652
# 69   3.756922e-01                     dti             3.907291
# 70   4.846849e-02  mths_since_last_delinq             7.940343
# 71   7.020200e-03  mths_since_last_delinq            10.962089
# 72   4.946431e-04  mths_since_last_delinq            14.347270
# 73   1.185531e-02  mths_since_last_delinq            10.610075
# 74   3.167814e-05  mths_since_last_record            26.031357
# 75   1.678724e-04  mths_since_last_record            35.607992
# 76   7.240039e-04  mths_since_last_record            29.309676
# 77   2.603883e-10  mths_since_last_record            41.503494
# 78   5.872193e-02  mths_since_last_record            14.886253
# 79   2.315476e-03  mths_since_last_record            19.718848
# 80            NaN                   grade             0.000000
# 81            NaN          home_ownership             0.000000
# 82            NaN              addr_state             0.000000
# 83            NaN     verification_status             0.000000
# 84            NaN                 purpose             0.000000
# 85            NaN     initial_list_status             0.000000
# 86            NaN                    term             0.000000
# 87            NaN              emp_length             0.000000
# 88            NaN      mths_since_issue_d             0.000000
# 89            NaN                int_rate             0.000000
# 90            NaN          inq_last_6mths             0.000000
# 91            NaN          acc_now_delinq             0.000000
# 92            NaN              annual_inc             0.000000
# 93            NaN                     dti             0.000000
# 94            NaN  mths_since_last_delinq             0.000000
# 95            NaN  mths_since_last_record             0.000000
#
#     Score - Preliminary  Difference
# 0                 313.0   -0.030004
# 1                  89.0    0.079032
# 2                  70.0    0.243642
# 3                  55.0    0.441369
# 4                  40.0    0.042545
# 5                  26.0   -0.264380
# 6                  12.0    0.484057
# 7                   8.0   -0.012608
# 8                   9.0    0.257249
# 9                   3.0    0.039173
# 10                  4.0   -0.460844
# 11                  5.0    0.354483
# 12                  5.0    0.086658
# 13                  6.0   -0.177471
# 14                 11.0    0.373485
# 15                  8.0    0.155528
# 16                 14.0   -0.452949
# 17                 19.0   -0.265223
# 18                 17.0   -0.294970
# 19                 20.0   -0.371259
# 20                 25.0    0.047652
# 21                 40.0   -0.410319
# 22                  6.0   -0.213168
# 23                 -1.0    0.223729
# 24                 24.0    0.498843
# 25                 15.0   -0.484318
# 26                 17.0    0.302975
# 27                 20.0   -0.495350
# 28                  4.0   -0.184195
# 29                  6.0    0.343537
# 30                  7.0    0.018889
# 31                  9.0    0.078301
# 32                  6.0   -0.313490
# 33                  4.0   -0.258474
# 34                 10.0   -0.090740
# 35                 82.0    0.020197
# 36                 66.0   -0.375528
# 37                 59.0    0.301144
# 38                 43.0   -0.343831
# 39                 31.0    0.108144
# 40                 12.0   -0.055266
# 41                 -6.0    0.344803
# 42                 69.0    0.091594
# 43                 44.0    0.452431
# 44                 24.0    0.198001
# 45                  9.0    0.207016
# 46                 52.0   -0.421606
# 47                 41.0   -0.104565
# 48                 25.0    0.220340
# 49                 15.0   -0.105152
# 50                 -5.0    0.461471
# 51                 -0.0    0.331394
# 52                  7.0   -0.198450
# 53                 13.0    0.397518
# 54                 19.0    0.409297
# 55                 24.0   -0.494537
# 56                 31.0    0.466537
# 57                 32.0   -0.170635
# 58                 38.0   -0.489267
# 59                 46.0    0.064994
# 60                 41.0   -0.267036
# 61                 19.0    0.456301
# 62                 27.0   -0.375631
# 63                 29.0   -0.049500
# 64                 24.0   -0.224048
# 65                 18.0   -0.227527
# 66                 11.0    0.455832
# 67                 10.0    0.280101
# 68                  7.0    0.065348
# 69                  4.0    0.092709
# 70                  8.0    0.059657
# 71                 11.0    0.037911
# 72                 14.0   -0.347270
# 73                 11.0    0.389925
# 74                 26.0   -0.031357
# 75                 36.0    0.392008
# 76                 29.0   -0.309676
# 77                 42.0    0.496506
# 78                 15.0    0.113747
# 79                 20.0    0.281152
# 80                  0.0    0.000000
# 81                  0.0    0.000000
# 82                  0.0    0.000000
# 83                  0.0    0.000000
# 84                  0.0    0.000000
# 85                  0.0    0.000000
# 86                  0.0    0.000000
# 87                  0.0    0.000000
# 88                  0.0    0.000000
# 89                  0.0    0.000000
# 90                  0.0    0.000000
# 91                  0.0    0.000000
# 92                  0.0    0.000000
# 93                  0.0    0.000000
# 94                  0.0    0.000000
# 95                  0.0    0.000000

# %%
df_scorecard['Score - Final'] = df_scorecard['Score - Preliminary']
df_scorecard['Score - Final'][50] = -6
df_scorecard
# Out:
# <ipython-input-125-bb0152ad6226>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_scorecard['Score - Final'][50] = -6
#     index                                  Feature name  Coefficients  \
# 0       0                                     Intercept     -1.363017
# 1       1                                       grade:A      1.150683
# 2       2                                       grade:B      0.902683
# 3       3                                       grade:C      0.706017
# 4       4                                       grade:D      0.517070
# 5       5                                       grade:E      0.339875
# 6       6                                       grade:F      0.149022
# 7       7                            home_ownership:OWN      0.103687
# 8       8                       home_ownership:MORTGAGE      0.113136
# 9       9                              addr_state:NM_VA      0.038315
# 10     10                                 addr_state:NY      0.057726
# 11     11                  addr_state:OK_TN_MO_LA_MD_NC      0.060115
# 12     12                                 addr_state:CA      0.063581
# 13     13                        addr_state:UT_KY_AZ_NJ      0.079940
# 14     14                     addr_state:AR_MI_PA_OH_MN      0.137513
# 15     15                     addr_state:RI_MA_DE_SD_IN      0.101512
# 16     16                           addr_state:GA_WA_OR      0.187029
# 17     17                              addr_state:WI_MT      0.249302
# 18     18                                 addr_state:TX      0.223806
# 19     19                              addr_state:IL_CT      0.263615
# 20     20                  addr_state:KS_SC_CO_VT_AK_MS      0.322896
# 21     21                  addr_state:WV_NH_WY_DC_ME_ID      0.522930
# 22     22              verification_status:Not Verified      0.080402
# 23     23           verification_status:Source Verified     -0.015836
# 24     24                           purpose:credit_card      0.304117
# 25     25                    purpose:debt_consolidation      0.200375
# 26     26                    purpose:oth__med__vacation      0.216068
# 27     27           purpose:major_purch__car__home_impr      0.265220
# 28     28                         initial_list_status:w      0.054146
# 29     29                                       term:36      0.073198
# 30     30                                  emp_length:1      0.090339
# 31     31                                emp_length:2-4      0.115451
# 32     32                                emp_length:5-6      0.081700
# 33     33                                emp_length:7-9      0.055107
# 34     34                                 emp_length:10      0.130579
# 35     35                        mths_since_issue_d:<38      1.060861
# 36     36                      mths_since_issue_d:38-39      0.858934
# 37     37                      mths_since_issue_d:40-41      0.759594
# 38     38                      mths_since_issue_d:42-48      0.560892
# 39     39                      mths_since_issue_d:49-52      0.399757
# 40     40                      mths_since_issue_d:53-64      0.156001
# 41     41                      mths_since_issue_d:65-84     -0.082105
# 42     42                               int_rate:<9.548      0.891710
# 43     43                         int_rate:9.548-12.025      0.563528
# 44     44                         int_rate:12.025-15.74      0.308010
# 45     45                         int_rate:15.74-20.281      0.113786
# 46     46                              inq_last_6mths:0      0.678363
# 47     47                            inq_last_6mths:1-2      0.531914
# 48     48                            inq_last_6mths:3-6      0.320662
# 49     49                            acc_now_delinq:>=1      0.195468
# 50     50                            annual_inc:20K-30K     -0.070674
# 51     51                            annual_inc:30K-40K     -0.004288
# 52     52                            annual_inc:40K-50K      0.093152
# 53     53                            annual_inc:50K-60K      0.163083
# 54     54                            annual_inc:60K-70K      0.240573
# 55     55                            annual_inc:70K-80K      0.316972
# 56     56                            annual_inc:80K-90K      0.395119
# 57     57                           annual_inc:90K-100K      0.416305
# 58     58                          annual_inc:100K-120K      0.498071
# 59     59                          annual_inc:120K-140K      0.594423
# 60     60                              annual_inc:>140K      0.534017
# 61     61                                     dti:<=1.4      0.239965
# 62     62                                   dti:1.4-3.5      0.354255
# 63     63                                   dti:3.5-7.7      0.375916
# 64     64                                  dti:7.7-10.5      0.313472
# 65     65                                 dti:10.5-16.1      0.235874
# 66     66                                 dti:16.1-20.3      0.136447
# 67     67                                 dti:20.3-21.7      0.125781
# 68     68                                 dti:21.7-22.4      0.089738
# 69     69                                   dti:22.4-35      0.050562
# 70     70                mths_since_last_delinq:Missing      0.102752
# 71     71                   mths_since_last_delinq:4-30      0.141855
# 72     72                  mths_since_last_delinq:31-56      0.185661
# 73     73                   mths_since_last_delinq:>=57      0.137300
# 74     74                mths_since_last_record:Missing      0.336859
# 75     75                   mths_since_last_record:3-20      0.460786
# 76     76                  mths_since_last_record:21-31      0.379282
# 77     77                  mths_since_last_record:32-80      0.537077
# 78     78                  mths_since_last_record:81-86      0.192636
# 79     79                    mths_since_last_record:>86      0.255172
# 80      0                                       grade:G      0.000000
# 81      1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 82      2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 83      3                  verification_status:Verified      0.000000
# 84      4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 85      5                         initial_list_status:f      0.000000
# 86      6                                       term:60      0.000000
# 87      7                                  emp_length:0      0.000000
# 88      8                        mths_since_issue_d:>84      0.000000
# 89      9                              int_rate:>20.281      0.000000
# 90     10                             inq_last_6mths:>6      0.000000
# 91     11                              acc_now_delinq:0      0.000000
# 92     12                               annual_inc:<20K      0.000000
# 93     13                                       dti:>35      0.000000
# 94     14                    mths_since_last_delinq:0-3      0.000000
# 95     15                    mths_since_last_record:0-2      0.000000
#
#          p_values   Original feature name  Score - Calculation  \
# 0             NaN               Intercept           313.030004
# 1    6.493398e-37                   grade            88.920968
# 2    8.562678e-50                   grade            69.756358
# 3    4.328151e-36                   grade            54.558631
# 4    2.846739e-22                   grade            39.957455
# 5    5.407915e-13                   grade            26.264380
# 6    2.340250e-03                   grade            11.515943
# 7    2.427123e-07          home_ownership             8.012608
# 8    2.380389e-19          home_ownership             8.742751
# 9    2.316105e-01              addr_state             2.960827
# 10   1.712761e-02              addr_state             4.460844
# 11   9.382653e-03              addr_state             4.645517
# 12   2.695528e-03              addr_state             4.913342
# 13   1.328778e-03              addr_state             6.177471
# 14   1.001046e-09              addr_state            10.626515
# 15   6.665786e-04              addr_state             7.844472
# 16   2.294597e-12              addr_state            14.452949
# 17   1.629901e-07              addr_state            19.265223
# 18   6.894934e-18              addr_state            17.294970
# 19   1.750119e-19              addr_state            20.371259
# 20   1.120202e-25              addr_state            24.952348
# 21   8.378406e-23              addr_state            40.410319
# 22   3.500395e-08     verification_status             6.213168
# 23   2.376157e-01     verification_status            -1.223729
# 24   5.128792e-27                 purpose            23.501157
# 25   1.231238e-14                 purpose            15.484318
# 26   3.656105e-12                 purpose            16.697025
# 27   1.940163e-17                 purpose            20.495350
# 28   3.365657e-05     initial_list_status             4.184195
# 29   1.504587e-07                    term             5.656463
# 30   4.841712e-04              emp_length             6.981111
# 31   8.191726e-10              emp_length             8.921699
# 32   1.298719e-04              emp_length             6.313490
# 33   7.940178e-03              emp_length             4.258474
# 34   1.196903e-12              emp_length            10.090740
# 35  2.492088e-175      mths_since_issue_d            81.979803
# 36  1.263264e-144      mths_since_issue_d            66.375528
# 37  2.259928e-119      mths_since_issue_d            58.698856
# 38   8.393180e-84      mths_since_issue_d            43.343831
# 39   3.871994e-38      mths_since_issue_d            30.891856
# 40   8.464982e-08      mths_since_issue_d            12.055266
# 41   4.922289e-03      mths_since_issue_d            -6.344803
# 42   9.942819e-32                int_rate            68.908406
# 43   1.356033e-36                int_rate            43.547569
# 44   4.578890e-17                int_rate            23.801999
# 45   8.543059e-05                int_rate             8.792984
# 46   7.812819e-15          inq_last_6mths            52.421606
# 47   1.055744e-09          inq_last_6mths            41.104565
# 48   2.579841e-04          inq_last_6mths            24.779660
# 49   6.505953e-02          acc_now_delinq            15.105152
# 50   9.224062e-02              annual_inc            -5.461471
# 51   9.151110e-01              annual_inc            -0.331394
# 52   2.015477e-02              annual_inc             7.198450
# 53   5.789103e-05              annual_inc            12.602482
# 54   6.471118e-09              annual_inc            18.590703
# 55   6.440899e-14              annual_inc            24.494537
# 56   2.871908e-19              annual_inc            30.533463
# 57   7.099694e-20              annual_inc            32.170635
# 58   2.925291e-28              annual_inc            38.489267
# 59   7.642023e-31              annual_inc            45.935006
# 60   5.887430e-30              annual_inc            41.267036
# 61   3.939726e-03                     dti            18.543699
# 62   3.835659e-07                     dti            27.375631
# 63   3.912500e-10                     dti            29.049500
# 64   1.516656e-07                     dti            24.224048
# 65   4.326273e-05                     dti            18.227527
# 66   1.816938e-02                     dti            10.544168
# 67   3.754793e-02                     dti             9.719899
# 68   1.645268e-01                     dti             6.934652
# 69   3.756922e-01                     dti             3.907291
# 70   4.846849e-02  mths_since_last_delinq             7.940343
# 71   7.020200e-03  mths_since_last_delinq            10.962089
# 72   4.946431e-04  mths_since_last_delinq            14.347270
# 73   1.185531e-02  mths_since_last_delinq            10.610075
# 74   3.167814e-05  mths_since_last_record            26.031357
# 75   1.678724e-04  mths_since_last_record            35.607992
# 76   7.240039e-04  mths_since_last_record            29.309676
# 77   2.603883e-10  mths_since_last_record            41.503494
# 78   5.872193e-02  mths_since_last_record            14.886253
# 79   2.315476e-03  mths_since_last_record            19.718848
# 80            NaN                   grade             0.000000
# 81            NaN          home_ownership             0.000000
# 82            NaN              addr_state             0.000000
# 83            NaN     verification_status             0.000000
# 84            NaN                 purpose             0.000000
# 85            NaN     initial_list_status             0.000000
# 86            NaN                    term             0.000000
# 87            NaN              emp_length             0.000000
# 88            NaN      mths_since_issue_d             0.000000
# 89            NaN                int_rate             0.000000
# 90            NaN          inq_last_6mths             0.000000
# 91            NaN          acc_now_delinq             0.000000
# 92            NaN              annual_inc             0.000000
# 93            NaN                     dti             0.000000
# 94            NaN  mths_since_last_delinq             0.000000
# 95            NaN  mths_since_last_record             0.000000
#
#     Score - Preliminary  Difference  Score - Final
# 0                 313.0   -0.030004          313.0
# 1                  89.0    0.079032           89.0
# 2                  70.0    0.243642           70.0
# 3                  55.0    0.441369           55.0
# 4                  40.0    0.042545           40.0
# 5                  26.0   -0.264380           26.0
# 6                  12.0    0.484057           12.0
# 7                   8.0   -0.012608            8.0
# 8                   9.0    0.257249            9.0
# 9                   3.0    0.039173            3.0
# 10                  4.0   -0.460844            4.0
# 11                  5.0    0.354483            5.0
# 12                  5.0    0.086658            5.0
# 13                  6.0   -0.177471            6.0
# 14                 11.0    0.373485           11.0
# 15                  8.0    0.155528            8.0
# 16                 14.0   -0.452949           14.0
# 17                 19.0   -0.265223           19.0
# 18                 17.0   -0.294970           17.0
# 19                 20.0   -0.371259           20.0
# 20                 25.0    0.047652           25.0
# 21                 40.0   -0.410319           40.0
# 22                  6.0   -0.213168            6.0
# 23                 -1.0    0.223729           -1.0
# 24                 24.0    0.498843           24.0
# 25                 15.0   -0.484318           15.0
# 26                 17.0    0.302975           17.0
# 27                 20.0   -0.495350           20.0
# 28                  4.0   -0.184195            4.0
# 29                  6.0    0.343537            6.0
# 30                  7.0    0.018889            7.0
# 31                  9.0    0.078301            9.0
# 32                  6.0   -0.313490            6.0
# 33                  4.0   -0.258474            4.0
# 34                 10.0   -0.090740           10.0
# 35                 82.0    0.020197           82.0
# 36                 66.0   -0.375528           66.0
# 37                 59.0    0.301144           59.0
# 38                 43.0   -0.343831           43.0
# 39                 31.0    0.108144           31.0
# 40                 12.0   -0.055266           12.0
# 41                 -6.0    0.344803           -6.0
# 42                 69.0    0.091594           69.0
# 43                 44.0    0.452431           44.0
# 44                 24.0    0.198001           24.0
# 45                  9.0    0.207016            9.0
# 46                 52.0   -0.421606           52.0
# 47                 41.0   -0.104565           41.0
# 48                 25.0    0.220340           25.0
# 49                 15.0   -0.105152           15.0
# 50                 -5.0    0.461471           -6.0
# 51                 -0.0    0.331394           -0.0
# 52                  7.0   -0.198450            7.0
# 53                 13.0    0.397518           13.0
# 54                 19.0    0.409297           19.0
# 55                 24.0   -0.494537           24.0
# 56                 31.0    0.466537           31.0
# 57                 32.0   -0.170635           32.0
# 58                 38.0   -0.489267           38.0
# 59                 46.0    0.064994           46.0
# 60                 41.0   -0.267036           41.0
# 61                 19.0    0.456301           19.0
# 62                 27.0   -0.375631           27.0
# 63                 29.0   -0.049500           29.0
# 64                 24.0   -0.224048           24.0
# 65                 18.0   -0.227527           18.0
# 66                 11.0    0.455832           11.0
# 67                 10.0    0.280101           10.0
# 68                  7.0    0.065348            7.0
# 69                  4.0    0.092709            4.0
# 70                  8.0    0.059657            8.0
# 71                 11.0    0.037911           11.0
# 72                 14.0   -0.347270           14.0
# 73                 11.0    0.389925           11.0
# 74                 26.0   -0.031357           26.0
# 75                 36.0    0.392008           36.0
# 76                 29.0   -0.309676           29.0
# 77                 42.0    0.496506           42.0
# 78                 15.0    0.113747           15.0
# 79                 20.0    0.281152           20.0
# 80                  0.0    0.000000            0.0
# 81                  0.0    0.000000            0.0
# 82                  0.0    0.000000            0.0
# 83                  0.0    0.000000            0.0
# 84                  0.0    0.000000            0.0
# 85                  0.0    0.000000            0.0
# 86                  0.0    0.000000            0.0
# 87                  0.0    0.000000            0.0
# 88                  0.0    0.000000            0.0
# 89                  0.0    0.000000            0.0
# 90                  0.0    0.000000            0.0
# 91                  0.0    0.000000            0.0
# 92                  0.0    0.000000            0.0
# 93                  0.0    0.000000            0.0
# 94                  0.0    0.000000            0.0
# 95                  0.0    0.000000            0.0

# %%
min_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].min().sum()
min_sum_score_prel
# Out:
# 300.0

# %%
max_sum_score_prel = df_scorecard.groupby('Original feature name')['Score - Final'].max().sum()
# Groups the data by the values of the 'Original feature name' column.
# Aggregates the data in the 'Coefficients' column, calculating their maximum.
# Sums all maximum values.
max_sum_score_prel
# Out:
# 850.0

# %% [markdown]
# ### Caclulating Credit Score

# %%
inputs_test_with_ref_cat.head()
# Out:
#         grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  grade:G  \
# 362514        0        0        1        0        0        0        0
# 288564        0        0        0        0        1        0        0
# 213591        0        0        1        0        0        0        0
# 263083        0        0        1        0        0        0        0
# 165001        1        0        0        0        0        0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514                                   0                   0
# 288564                                   0                   0
# 213591                                   0                   0
# 263083                                   0                   0
# 165001                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  inq_last_6mths:0  inq_last_6mths:1-2  \
# 362514                 0                 1                   0
# 288564                 1                 1                   0
# 213591                 0                 1                   0
# 263083                 0                 1                   0
# 165001                 0                 1                   0
#
#         inq_last_6mths:3-6  inq_last_6mths:>6  acc_now_delinq:0  \
# 362514                   0                  0                 1
# 288564                   0                  0                 1
# 213591                   0                  0                 1
# 263083                   0                  0                 1
# 165001                   0                  0                 1
#
#         acc_now_delinq:>=1  annual_inc:<20K  annual_inc:20K-30K  \
# 362514                   0                0                   0
# 288564                   0                0                   0
# 213591                   0                0                   0
# 263083                   0                0                   0
# 165001                   0                0                   0
#
#         annual_inc:30K-40K  annual_inc:40K-50K  annual_inc:50K-60K  \
# 362514                   0                   0                   0
# 288564                   0                   0                   1
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:60K-70K  annual_inc:70K-80K  annual_inc:80K-90K  \
# 362514                   1                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   1                   0                   0
# 165001                   0                   0                   1
#
#         annual_inc:90K-100K  annual_inc:100K-120K  annual_inc:120K-140K  \
# 362514                    0                     0                     0
# 288564                    0                     0                     0
# 213591                    0                     0                     0
# 263083                    0                     0                     0
# 165001                    0                     0                     0
#
#         annual_inc:>140K  dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  \
# 362514                 0          0            0            0             1
# 288564                 0          0            0            0             0
# 213591                 1          0            0            0             0
# 263083                 0          0            0            0             0
# 165001                 0          0            0            0             1
#
#         dti:10.5-16.1  dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  \
# 362514              0              0              0              0
# 288564              0              0              0              0
# 213591              1              0              0              0
# 263083              0              1              0              0
# 165001              0              0              0              0
#
#         dti:22.4-35  dti:>35  mths_since_last_delinq:Missing  \
# 362514            0        0                               1
# 288564            1        0                               0
# 213591            0        0                               0
# 263083            0        0                               1
# 165001            0        0                               0
#
#         mths_since_last_delinq:0-3  mths_since_last_delinq:4-30  \
# 362514                           0                            0
# 288564                           1                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:0-2  \
# 362514                               1                           0
# 288564                               1                           0
# 213591                               1                           0
# 263083                               1                           0
# 165001                               1                           0
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>86
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0

# %%
df_scorecard
# Out:
#     index                                  Feature name  Coefficients  \
# 0       0                                     Intercept     -1.363017
# 1       1                                       grade:A      1.150683
# 2       2                                       grade:B      0.902683
# 3       3                                       grade:C      0.706017
# 4       4                                       grade:D      0.517070
# 5       5                                       grade:E      0.339875
# 6       6                                       grade:F      0.149022
# 7       7                            home_ownership:OWN      0.103687
# 8       8                       home_ownership:MORTGAGE      0.113136
# 9       9                              addr_state:NM_VA      0.038315
# 10     10                                 addr_state:NY      0.057726
# 11     11                  addr_state:OK_TN_MO_LA_MD_NC      0.060115
# 12     12                                 addr_state:CA      0.063581
# 13     13                        addr_state:UT_KY_AZ_NJ      0.079940
# 14     14                     addr_state:AR_MI_PA_OH_MN      0.137513
# 15     15                     addr_state:RI_MA_DE_SD_IN      0.101512
# 16     16                           addr_state:GA_WA_OR      0.187029
# 17     17                              addr_state:WI_MT      0.249302
# 18     18                                 addr_state:TX      0.223806
# 19     19                              addr_state:IL_CT      0.263615
# 20     20                  addr_state:KS_SC_CO_VT_AK_MS      0.322896
# 21     21                  addr_state:WV_NH_WY_DC_ME_ID      0.522930
# 22     22              verification_status:Not Verified      0.080402
# 23     23           verification_status:Source Verified     -0.015836
# 24     24                           purpose:credit_card      0.304117
# 25     25                    purpose:debt_consolidation      0.200375
# 26     26                    purpose:oth__med__vacation      0.216068
# 27     27           purpose:major_purch__car__home_impr      0.265220
# 28     28                         initial_list_status:w      0.054146
# 29     29                                       term:36      0.073198
# 30     30                                  emp_length:1      0.090339
# 31     31                                emp_length:2-4      0.115451
# 32     32                                emp_length:5-6      0.081700
# 33     33                                emp_length:7-9      0.055107
# 34     34                                 emp_length:10      0.130579
# 35     35                        mths_since_issue_d:<38      1.060861
# 36     36                      mths_since_issue_d:38-39      0.858934
# 37     37                      mths_since_issue_d:40-41      0.759594
# 38     38                      mths_since_issue_d:42-48      0.560892
# 39     39                      mths_since_issue_d:49-52      0.399757
# 40     40                      mths_since_issue_d:53-64      0.156001
# 41     41                      mths_since_issue_d:65-84     -0.082105
# 42     42                               int_rate:<9.548      0.891710
# 43     43                         int_rate:9.548-12.025      0.563528
# 44     44                         int_rate:12.025-15.74      0.308010
# 45     45                         int_rate:15.74-20.281      0.113786
# 46     46                              inq_last_6mths:0      0.678363
# 47     47                            inq_last_6mths:1-2      0.531914
# 48     48                            inq_last_6mths:3-6      0.320662
# 49     49                            acc_now_delinq:>=1      0.195468
# 50     50                            annual_inc:20K-30K     -0.070674
# 51     51                            annual_inc:30K-40K     -0.004288
# 52     52                            annual_inc:40K-50K      0.093152
# 53     53                            annual_inc:50K-60K      0.163083
# 54     54                            annual_inc:60K-70K      0.240573
# 55     55                            annual_inc:70K-80K      0.316972
# 56     56                            annual_inc:80K-90K      0.395119
# 57     57                           annual_inc:90K-100K      0.416305
# 58     58                          annual_inc:100K-120K      0.498071
# 59     59                          annual_inc:120K-140K      0.594423
# 60     60                              annual_inc:>140K      0.534017
# 61     61                                     dti:<=1.4      0.239965
# 62     62                                   dti:1.4-3.5      0.354255
# 63     63                                   dti:3.5-7.7      0.375916
# 64     64                                  dti:7.7-10.5      0.313472
# 65     65                                 dti:10.5-16.1      0.235874
# 66     66                                 dti:16.1-20.3      0.136447
# 67     67                                 dti:20.3-21.7      0.125781
# 68     68                                 dti:21.7-22.4      0.089738
# 69     69                                   dti:22.4-35      0.050562
# 70     70                mths_since_last_delinq:Missing      0.102752
# 71     71                   mths_since_last_delinq:4-30      0.141855
# 72     72                  mths_since_last_delinq:31-56      0.185661
# 73     73                   mths_since_last_delinq:>=57      0.137300
# 74     74                mths_since_last_record:Missing      0.336859
# 75     75                   mths_since_last_record:3-20      0.460786
# 76     76                  mths_since_last_record:21-31      0.379282
# 77     77                  mths_since_last_record:32-80      0.537077
# 78     78                  mths_since_last_record:81-86      0.192636
# 79     79                    mths_since_last_record:>86      0.255172
# 80      0                                       grade:G      0.000000
# 81      1            home_ownership:RENT_OTHER_NONE_ANY      0.000000
# 82      2               addr_state:ND_NE_IA_NV_FL_HI_AL      0.000000
# 83      3                  verification_status:Verified      0.000000
# 84      4  purpose:educ__sm_b__wedd__ren_en__mov__house      0.000000
# 85      5                         initial_list_status:f      0.000000
# 86      6                                       term:60      0.000000
# 87      7                                  emp_length:0      0.000000
# 88      8                        mths_since_issue_d:>84      0.000000
# 89      9                              int_rate:>20.281      0.000000
# 90     10                             inq_last_6mths:>6      0.000000
# 91     11                              acc_now_delinq:0      0.000000
# 92     12                               annual_inc:<20K      0.000000
# 93     13                                       dti:>35      0.000000
# 94     14                    mths_since_last_delinq:0-3      0.000000
# 95     15                    mths_since_last_record:0-2      0.000000
#
#          p_values   Original feature name  Score - Calculation  \
# 0             NaN               Intercept           313.030004
# 1    6.493398e-37                   grade            88.920968
# 2    8.562678e-50                   grade            69.756358
# 3    4.328151e-36                   grade            54.558631
# 4    2.846739e-22                   grade            39.957455
# 5    5.407915e-13                   grade            26.264380
# 6    2.340250e-03                   grade            11.515943
# 7    2.427123e-07          home_ownership             8.012608
# 8    2.380389e-19          home_ownership             8.742751
# 9    2.316105e-01              addr_state             2.960827
# 10   1.712761e-02              addr_state             4.460844
# 11   9.382653e-03              addr_state             4.645517
# 12   2.695528e-03              addr_state             4.913342
# 13   1.328778e-03              addr_state             6.177471
# 14   1.001046e-09              addr_state            10.626515
# 15   6.665786e-04              addr_state             7.844472
# 16   2.294597e-12              addr_state            14.452949
# 17   1.629901e-07              addr_state            19.265223
# 18   6.894934e-18              addr_state            17.294970
# 19   1.750119e-19              addr_state            20.371259
# 20   1.120202e-25              addr_state            24.952348
# 21   8.378406e-23              addr_state            40.410319
# 22   3.500395e-08     verification_status             6.213168
# 23   2.376157e-01     verification_status            -1.223729
# 24   5.128792e-27                 purpose            23.501157
# 25   1.231238e-14                 purpose            15.484318
# 26   3.656105e-12                 purpose            16.697025
# 27   1.940163e-17                 purpose            20.495350
# 28   3.365657e-05     initial_list_status             4.184195
# 29   1.504587e-07                    term             5.656463
# 30   4.841712e-04              emp_length             6.981111
# 31   8.191726e-10              emp_length             8.921699
# 32   1.298719e-04              emp_length             6.313490
# 33   7.940178e-03              emp_length             4.258474
# 34   1.196903e-12              emp_length            10.090740
# 35  2.492088e-175      mths_since_issue_d            81.979803
# 36  1.263264e-144      mths_since_issue_d            66.375528
# 37  2.259928e-119      mths_since_issue_d            58.698856
# 38   8.393180e-84      mths_since_issue_d            43.343831
# 39   3.871994e-38      mths_since_issue_d            30.891856
# 40   8.464982e-08      mths_since_issue_d            12.055266
# 41   4.922289e-03      mths_since_issue_d            -6.344803
# 42   9.942819e-32                int_rate            68.908406
# 43   1.356033e-36                int_rate            43.547569
# 44   4.578890e-17                int_rate            23.801999
# 45   8.543059e-05                int_rate             8.792984
# 46   7.812819e-15          inq_last_6mths            52.421606
# 47   1.055744e-09          inq_last_6mths            41.104565
# 48   2.579841e-04          inq_last_6mths            24.779660
# 49   6.505953e-02          acc_now_delinq            15.105152
# 50   9.224062e-02              annual_inc            -5.461471
# 51   9.151110e-01              annual_inc            -0.331394
# 52   2.015477e-02              annual_inc             7.198450
# 53   5.789103e-05              annual_inc            12.602482
# 54   6.471118e-09              annual_inc            18.590703
# 55   6.440899e-14              annual_inc            24.494537
# 56   2.871908e-19              annual_inc            30.533463
# 57   7.099694e-20              annual_inc            32.170635
# 58   2.925291e-28              annual_inc            38.489267
# 59   7.642023e-31              annual_inc            45.935006
# 60   5.887430e-30              annual_inc            41.267036
# 61   3.939726e-03                     dti            18.543699
# 62   3.835659e-07                     dti            27.375631
# 63   3.912500e-10                     dti            29.049500
# 64   1.516656e-07                     dti            24.224048
# 65   4.326273e-05                     dti            18.227527
# 66   1.816938e-02                     dti            10.544168
# 67   3.754793e-02                     dti             9.719899
# 68   1.645268e-01                     dti             6.934652
# 69   3.756922e-01                     dti             3.907291
# 70   4.846849e-02  mths_since_last_delinq             7.940343
# 71   7.020200e-03  mths_since_last_delinq            10.962089
# 72   4.946431e-04  mths_since_last_delinq            14.347270
# 73   1.185531e-02  mths_since_last_delinq            10.610075
# 74   3.167814e-05  mths_since_last_record            26.031357
# 75   1.678724e-04  mths_since_last_record            35.607992
# 76   7.240039e-04  mths_since_last_record            29.309676
# 77   2.603883e-10  mths_since_last_record            41.503494
# 78   5.872193e-02  mths_since_last_record            14.886253
# 79   2.315476e-03  mths_since_last_record            19.718848
# 80            NaN                   grade             0.000000
# 81            NaN          home_ownership             0.000000
# 82            NaN              addr_state             0.000000
# 83            NaN     verification_status             0.000000
# 84            NaN                 purpose             0.000000
# 85            NaN     initial_list_status             0.000000
# 86            NaN                    term             0.000000
# 87            NaN              emp_length             0.000000
# 88            NaN      mths_since_issue_d             0.000000
# 89            NaN                int_rate             0.000000
# 90            NaN          inq_last_6mths             0.000000
# 91            NaN          acc_now_delinq             0.000000
# 92            NaN              annual_inc             0.000000
# 93            NaN                     dti             0.000000
# 94            NaN  mths_since_last_delinq             0.000000
# 95            NaN  mths_since_last_record             0.000000
#
#     Score - Preliminary  Difference  Score - Final
# 0                 313.0   -0.030004          313.0
# 1                  89.0    0.079032           89.0
# 2                  70.0    0.243642           70.0
# 3                  55.0    0.441369           55.0
# 4                  40.0    0.042545           40.0
# 5                  26.0   -0.264380           26.0
# 6                  12.0    0.484057           12.0
# 7                   8.0   -0.012608            8.0
# 8                   9.0    0.257249            9.0
# 9                   3.0    0.039173            3.0
# 10                  4.0   -0.460844            4.0
# 11                  5.0    0.354483            5.0
# 12                  5.0    0.086658            5.0
# 13                  6.0   -0.177471            6.0
# 14                 11.0    0.373485           11.0
# 15                  8.0    0.155528            8.0
# 16                 14.0   -0.452949           14.0
# 17                 19.0   -0.265223           19.0
# 18                 17.0   -0.294970           17.0
# 19                 20.0   -0.371259           20.0
# 20                 25.0    0.047652           25.0
# 21                 40.0   -0.410319           40.0
# 22                  6.0   -0.213168            6.0
# 23                 -1.0    0.223729           -1.0
# 24                 24.0    0.498843           24.0
# 25                 15.0   -0.484318           15.0
# 26                 17.0    0.302975           17.0
# 27                 20.0   -0.495350           20.0
# 28                  4.0   -0.184195            4.0
# 29                  6.0    0.343537            6.0
# 30                  7.0    0.018889            7.0
# 31                  9.0    0.078301            9.0
# 32                  6.0   -0.313490            6.0
# 33                  4.0   -0.258474            4.0
# 34                 10.0   -0.090740           10.0
# 35                 82.0    0.020197           82.0
# 36                 66.0   -0.375528           66.0
# 37                 59.0    0.301144           59.0
# 38                 43.0   -0.343831           43.0
# 39                 31.0    0.108144           31.0
# 40                 12.0   -0.055266           12.0
# 41                 -6.0    0.344803           -6.0
# 42                 69.0    0.091594           69.0
# 43                 44.0    0.452431           44.0
# 44                 24.0    0.198001           24.0
# 45                  9.0    0.207016            9.0
# 46                 52.0   -0.421606           52.0
# 47                 41.0   -0.104565           41.0
# 48                 25.0    0.220340           25.0
# 49                 15.0   -0.105152           15.0
# 50                 -5.0    0.461471           -6.0
# 51                 -0.0    0.331394           -0.0
# 52                  7.0   -0.198450            7.0
# 53                 13.0    0.397518           13.0
# 54                 19.0    0.409297           19.0
# 55                 24.0   -0.494537           24.0
# 56                 31.0    0.466537           31.0
# 57                 32.0   -0.170635           32.0
# 58                 38.0   -0.489267           38.0
# 59                 46.0    0.064994           46.0
# 60                 41.0   -0.267036           41.0
# 61                 19.0    0.456301           19.0
# 62                 27.0   -0.375631           27.0
# 63                 29.0   -0.049500           29.0
# 64                 24.0   -0.224048           24.0
# 65                 18.0   -0.227527           18.0
# 66                 11.0    0.455832           11.0
# 67                 10.0    0.280101           10.0
# 68                  7.0    0.065348            7.0
# 69                  4.0    0.092709            4.0
# 70                  8.0    0.059657            8.0
# 71                 11.0    0.037911           11.0
# 72                 14.0   -0.347270           14.0
# 73                 11.0    0.389925           11.0
# 74                 26.0   -0.031357           26.0
# 75                 36.0    0.392008           36.0
# 76                 29.0   -0.309676           29.0
# 77                 42.0    0.496506           42.0
# 78                 15.0    0.113747           15.0
# 79                 20.0    0.281152           20.0
# 80                  0.0    0.000000            0.0
# 81                  0.0    0.000000            0.0
# 82                  0.0    0.000000            0.0
# 83                  0.0    0.000000            0.0
# 84                  0.0    0.000000            0.0
# 85                  0.0    0.000000            0.0
# 86                  0.0    0.000000            0.0
# 87                  0.0    0.000000            0.0
# 88                  0.0    0.000000            0.0
# 89                  0.0    0.000000            0.0
# 90                  0.0    0.000000            0.0
# 91                  0.0    0.000000            0.0
# 92                  0.0    0.000000            0.0
# 93                  0.0    0.000000            0.0
# 94                  0.0    0.000000            0.0
# 95                  0.0    0.000000            0.0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat

# %%
inputs_test_with_ref_cat_w_intercept.insert(0, 'Intercept', 1)

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         grade:G  home_ownership:RENT_OTHER_NONE_ANY  home_ownership:OWN  \
# 362514        0                                   0                   0
# 288564        0                                   0                   0
# 213591        0                                   0                   0
# 263083        0                                   0                   0
# 165001        0                                   0                   0
#
#         home_ownership:MORTGAGE  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                        1                                0
# 288564                        1                                0
# 213591                        1                                0
# 263083                        1                                0
# 165001                        1                                0
#
#         addr_state:NM_VA  addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  \
# 362514                 0              0                             0
# 288564                 0              0                             0
# 213591                 0              0                             0
# 263083                 0              0                             0
# 165001                 0              0                             0
#
#         addr_state:CA  addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514              1                       0                          0
# 288564              0                       0                          0
# 213591              0                       1                          0
# 263083              0                       0                          1
# 165001              0                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  verification_status:Verified  \
# 362514                                    0                             1
# 288564                                    0                             1
# 213591                                    0                             1
# 263083                                    1                             0
# 165001                                    0                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  purpose:credit_card  \
# 362514                                             0                    0
# 288564                                             0                    1
# 213591                                             0                    0
# 263083                                             0                    0
# 165001                                             0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:f  \
# 362514                                    1                      1
# 288564                                    0                      0
# 213591                                    0                      1
# 263083                                    0                      0
# 165001                                    0                      1
#
#         initial_list_status:w  term:36  term:60  emp_length:0  emp_length:1  \
# 362514                      0        0        1             1             0
# 288564                      1        0        1             0             0
# 213591                      0        1        0             0             1
# 263083                      1        0        1             0             0
# 165001                      0        1        0             0             0
#
#         emp_length:2-4  emp_length:5-6  emp_length:7-9  emp_length:10  \
# 362514               0               0               0              0
# 288564               0               0               0              1
# 213591               0               0               0              0
# 263083               1               0               0              0
# 165001               0               0               0              1
#
#         mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514                       0                         0
# 288564                       0                         1
# 213591                       0                         0
# 263083                       1                         0
# 165001                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  mths_since_issue_d:>84  int_rate:<9.548  \
# 362514                         0                       0                0
# 288564                         0                       0                0
# 213591                         1                       0                0
# 263083                         0                       0                0
# 165001                         0                       0                1
#
#         int_rate:9.548-12.025  int_rate:12.025-15.74  int_rate:15.74-20.281  \
# 362514                      0                      1                      0
# 288564                      0                      0                      0
# 213591                      0                      1                      0
# 263083                      0                      1                      0
# 165001                      0                      0                      0
#
#         int_rate:>20.281  inq_last_6mths:0  inq_last_6mths:1-2  \
# 362514                 0                 1                   0
# 288564                 1                 1                   0
# 213591                 0                 1                   0
# 263083                 0                 1                   0
# 165001                 0                 1                   0
#
#         inq_last_6mths:3-6  inq_last_6mths:>6  acc_now_delinq:0  \
# 362514                   0                  0                 1
# 288564                   0                  0                 1
# 213591                   0                  0                 1
# 263083                   0                  0                 1
# 165001                   0                  0                 1
#
#         acc_now_delinq:>=1  annual_inc:<20K  annual_inc:20K-30K  \
# 362514                   0                0                   0
# 288564                   0                0                   0
# 213591                   0                0                   0
# 263083                   0                0                   0
# 165001                   0                0                   0
#
#         annual_inc:30K-40K  annual_inc:40K-50K  annual_inc:50K-60K  \
# 362514                   0                   0                   0
# 288564                   0                   0                   1
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:60K-70K  annual_inc:70K-80K  annual_inc:80K-90K  \
# 362514                   1                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   1                   0                   0
# 165001                   0                   0                   1
#
#         annual_inc:90K-100K  annual_inc:100K-120K  annual_inc:120K-140K  \
# 362514                    0                     0                     0
# 288564                    0                     0                     0
# 213591                    0                     0                     0
# 263083                    0                     0                     0
# 165001                    0                     0                     0
#
#         annual_inc:>140K  dti:<=1.4  dti:1.4-3.5  dti:3.5-7.7  dti:7.7-10.5  \
# 362514                 0          0            0            0             1
# 288564                 0          0            0            0             0
# 213591                 1          0            0            0             0
# 263083                 0          0            0            0             0
# 165001                 0          0            0            0             1
#
#         dti:10.5-16.1  dti:16.1-20.3  dti:20.3-21.7  dti:21.7-22.4  \
# 362514              0              0              0              0
# 288564              0              0              0              0
# 213591              1              0              0              0
# 263083              0              1              0              0
# 165001              0              0              0              0
#
#         dti:22.4-35  dti:>35  mths_since_last_delinq:Missing  \
# 362514            0        0                               1
# 288564            1        0                               0
# 213591            0        0                               0
# 263083            0        0                               1
# 165001            0        0                               0
#
#         mths_since_last_delinq:0-3  mths_since_last_delinq:4-30  \
# 362514                           0                            0
# 288564                           1                            0
# 213591                           0                            0
# 263083                           0                            0
# 165001                           0                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:0-2  \
# 362514                               1                           0
# 288564                               1                           0
# 213591                               1                           0
# 263083                               1                           0
# 165001                               1                           0
#
#         mths_since_last_record:3-20  mths_since_last_record:21-31  \
# 362514                            0                             0
# 288564                            0                             0
# 213591                            0                             0
# 263083                            0                             0
# 165001                            0                             0
#
#         mths_since_last_record:32-80  mths_since_last_record:81-86  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:>86
# 362514                           0
# 288564                           0
# 213591                           0
# 263083                           0
# 165001                           0

# %%
inputs_test_with_ref_cat_w_intercept = inputs_test_with_ref_cat_w_intercept[df_scorecard['Feature name'].values]
# from the 'inputs_test_with_ref_cat_w_intercept' dataframe, we keep only the columns with column names,
#exactly equal to the row values of the 'Feature name' column from the 'df_scorecard' dataframe.

# %%
inputs_test_with_ref_cat_w_intercept.head()
# Out:
#         Intercept  grade:A  grade:B  grade:C  grade:D  grade:E  grade:F  \
# 362514          1        0        0        1        0        0        0
# 288564          1        0        0        0        0        1        0
# 213591          1        0        0        1        0        0        0
# 263083          1        0        0        1        0        0        0
# 165001          1        1        0        0        0        0        0
#
#         home_ownership:OWN  home_ownership:MORTGAGE  addr_state:NM_VA  \
# 362514                   0                        1                 0
# 288564                   0                        1                 0
# 213591                   0                        1                 0
# 263083                   0                        1                 0
# 165001                   0                        1                 0
#
#         addr_state:NY  addr_state:OK_TN_MO_LA_MD_NC  addr_state:CA  \
# 362514              0                             0              1
# 288564              0                             0              0
# 213591              0                             0              0
# 263083              0                             0              0
# 165001              0                             0              0
#
#         addr_state:UT_KY_AZ_NJ  addr_state:AR_MI_PA_OH_MN  \
# 362514                       0                          0
# 288564                       0                          0
# 213591                       1                          0
# 263083                       0                          1
# 165001                       0                          1
#
#         addr_state:RI_MA_DE_SD_IN  addr_state:GA_WA_OR  addr_state:WI_MT  \
# 362514                          0                    0                 0
# 288564                          1                    0                 0
# 213591                          0                    0                 0
# 263083                          0                    0                 0
# 165001                          0                    0                 0
#
#         addr_state:TX  addr_state:IL_CT  addr_state:KS_SC_CO_VT_AK_MS  \
# 362514              0                 0                             0
# 288564              0                 0                             0
# 213591              0                 0                             0
# 263083              0                 0                             0
# 165001              0                 0                             0
#
#         addr_state:WV_NH_WY_DC_ME_ID  verification_status:Not Verified  \
# 362514                             0                                 0
# 288564                             0                                 0
# 213591                             0                                 0
# 263083                             0                                 0
# 165001                             0                                 0
#
#         verification_status:Source Verified  purpose:credit_card  \
# 362514                                    0                    0
# 288564                                    0                    1
# 213591                                    0                    0
# 263083                                    1                    0
# 165001                                    0                    0
#
#         purpose:debt_consolidation  purpose:oth__med__vacation  \
# 362514                           0                           0
# 288564                           0                           0
# 213591                           1                           0
# 263083                           1                           0
# 165001                           1                           0
#
#         purpose:major_purch__car__home_impr  initial_list_status:w  term:36  \
# 362514                                    1                      0        0
# 288564                                    0                      1        0
# 213591                                    0                      0        1
# 263083                                    0                      1        0
# 165001                                    0                      0        1
#
#         emp_length:1  emp_length:2-4  emp_length:5-6  emp_length:7-9  \
# 362514             0               0               0               0
# 288564             0               0               0               0
# 213591             1               0               0               0
# 263083             0               1               0               0
# 165001             0               0               0               0
#
#         emp_length:10  mths_since_issue_d:<38  mths_since_issue_d:38-39  \
# 362514              0                       0                         0
# 288564              1                       0                         1
# 213591              0                       0                         0
# 263083              0                       1                         0
# 165001              1                       0                         0
#
#         mths_since_issue_d:40-41  mths_since_issue_d:42-48  \
# 362514                         1                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         0
#
#         mths_since_issue_d:49-52  mths_since_issue_d:53-64  \
# 362514                         0                         0
# 288564                         0                         0
# 213591                         0                         0
# 263083                         0                         0
# 165001                         0                         1
#
#         mths_since_issue_d:65-84  int_rate:<9.548  int_rate:9.548-12.025  \
# 362514                         0                0                      0
# 288564                         0                0                      0
# 213591                         1                0                      0
# 263083                         0                0                      0
# 165001                         0                1                      0
#
#         int_rate:12.025-15.74  int_rate:15.74-20.281  inq_last_6mths:0  \
# 362514                      1                      0                 1
# 288564                      0                      0                 1
# 213591                      1                      0                 1
# 263083                      1                      0                 1
# 165001                      0                      0                 1
#
#         inq_last_6mths:1-2  inq_last_6mths:3-6  acc_now_delinq:>=1  \
# 362514                   0                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:20K-30K  annual_inc:30K-40K  annual_inc:40K-50K  \
# 362514                   0                   0                   0
# 288564                   0                   0                   0
# 213591                   0                   0                   0
# 263083                   0                   0                   0
# 165001                   0                   0                   0
#
#         annual_inc:50K-60K  annual_inc:60K-70K  annual_inc:70K-80K  \
# 362514                   0                   1                   0
# 288564                   1                   0                   0
# 213591                   0                   0                   0
# 263083                   0                   1                   0
# 165001                   0                   0                   0
#
#         annual_inc:80K-90K  annual_inc:90K-100K  annual_inc:100K-120K  \
# 362514                   0                    0                     0
# 288564                   0                    0                     0
# 213591                   0                    0                     0
# 263083                   0                    0                     0
# 165001                   1                    0                     0
#
#         annual_inc:120K-140K  annual_inc:>140K  dti:<=1.4  dti:1.4-3.5  \
# 362514                     0                 0          0            0
# 288564                     0                 0          0            0
# 213591                     0                 1          0            0
# 263083                     0                 0          0            0
# 165001                     0                 0          0            0
#
#         dti:3.5-7.7  dti:7.7-10.5  dti:10.5-16.1  dti:16.1-20.3  \
# 362514            0             1              0              0
# 288564            0             0              0              0
# 213591            0             0              1              0
# 263083            0             0              0              1
# 165001            0             1              0              0
#
#         dti:20.3-21.7  dti:21.7-22.4  dti:22.4-35  \
# 362514              0              0            0
# 288564              0              0            1
# 213591              0              0            0
# 263083              0              0            0
# 165001              0              0            0
#
#         mths_since_last_delinq:Missing  mths_since_last_delinq:4-30  \
# 362514                               1                            0
# 288564                               0                            0
# 213591                               0                            0
# 263083                               1                            0
# 165001                               0                            0
#
#         mths_since_last_delinq:31-56  mths_since_last_delinq:>=57  \
# 362514                             0                            0
# 288564                             0                            0
# 213591                             1                            0
# 263083                             0                            0
# 165001                             1                            0
#
#         mths_since_last_record:Missing  mths_since_last_record:3-20  \
# 362514                               1                            0
# 288564                               1                            0
# 213591                               1                            0
# 263083                               1                            0
# 165001                               1                            0
#
#         mths_since_last_record:21-31  mths_since_last_record:32-80  \
# 362514                             0                             0
# 288564                             0                             0
# 213591                             0                             0
# 263083                             0                             0
# 165001                             0                             0
#
#         mths_since_last_record:81-86  mths_since_last_record:>86  grade:G  \
# 362514                             0                           0        0
# 288564                             0                           0        0
# 213591                             0                           0        0
# 263083                             0                           0        0
# 165001                             0                           0        0
#
#         home_ownership:RENT_OTHER_NONE_ANY  addr_state:ND_NE_IA_NV_FL_HI_AL  \
# 362514                                   0                                0
# 288564                                   0                                0
# 213591                                   0                                0
# 263083                                   0                                0
# 165001                                   0                                0
#
#         verification_status:Verified  \
# 362514                             1
# 288564                             1
# 213591                             1
# 263083                             0
# 165001                             1
#
#         purpose:educ__sm_b__wedd__ren_en__mov__house  initial_list_status:f  \
# 362514                                             0                      1
# 288564                                             0                      0
# 213591                                             0                      1
# 263083                                             0                      0
# 165001                                             0                      1
#
#         term:60  emp_length:0  mths_since_issue_d:>84  int_rate:>20.281  \
# 362514        1             1                       0                 0
# 288564        1             0                       0                 1
# 213591        0             0                       0                 0
# 263083        1             0                       0                 0
# 165001        0             0                       0                 0
#
#         inq_last_6mths:>6  acc_now_delinq:0  annual_inc:<20K  dti:>35  \
# 362514                  0                 1                0        0
# 288564                  0                 1                0        0
# 213591                  0                 1                0        0
# 263083                  0                 1                0        0
# 165001                  0                 1                0        0
#
#         mths_since_last_delinq:0-3  mths_since_last_record:0-2
# 362514                           0                           0
# 288564                           1                           0
# 213591                           0                           0
# 263083                           0                           0
# 165001                           0                           0

# %%
scorecard_scores = df_scorecard['Score - Final']

# %%
inputs_test_with_ref_cat_w_intercept.shape
# Out:
# (93257, 96)

# %%
scorecard_scores.shape
# Out:
# (96,)

# %%
scorecard_scores = scorecard_scores.values.reshape(96, 1)

# %%
scorecard_scores.shape
# Out:
# (96, 1)

# %%
y_scores = inputs_test_with_ref_cat_w_intercept.dot(scorecard_scores)
# Here we multiply the values of each row of the dataframe by the values of each column of the variable,
# which is an argument of the 'dot' method, and sum them. It's essentially the sum of the products.

# %%
y_scores.head()
# Out:
#             0
# 362514  614.0
# 288564  555.0
# 213591  580.0
# 263083  637.0
# 165001  681.0

# %%
y_scores.tail()
# Out:
#             0
# 115     574.0
# 296284  673.0
# 61777   696.0
# 91763   659.0
# 167512  652.0

# %%
inputs_train_with_ref_cat.to_csv('inputs_train_with_ref_cat.csv')

# %%
df_scorecard.to_csv('df_scorecard.csv')
